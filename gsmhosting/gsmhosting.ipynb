# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import re
from datetime import datetime

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Thiết lập chế độ headless cho Chrome
chrome_options = Options()
chrome_options.add_argument("--headless")  # Kích hoạt chế độ headless
# chrome_options.add_argument("--disable-gpu")  # Vô hiệu hóa GPU (giúp chạy ổn định hơn trên Windows)
# chrome_options.add_argument("--no-sandbox")  # Tùy chọn an toàn, đặc biệt khi chạy trong container

# Khởi tạo trình duyệt Chrome với các tùy chọn
driver = webdriver.Chrome(options=chrome_options)

# %%
driver.get("https://forum.gsmhosting.com/vbb/f209/")

links = []
raw_links = driver.find_elements(By.CLASS_NAME, "alt1Active")
for link in raw_links:
    a_tag = link.find_element(By.TAG_NAME, "a")
    title = link.text
    href = a_tag.get_attribute("href")

    links.append({'title': title, 'link':href})
for i, link in enumerate(links):
    print(f"{i + 1}: {link['title']} \n{link['link']} \n")
# Out:
# 1: AMT-dongle
# https://forum.gsmhosting.com/vbb/f1096/
#
# 2: ART (Android Root Tool)
# https://forum.gsmhosting.com/vbb/f1134/
#
# 3: Android Multi Tool (AMT)
# https://forum.gsmhosting.com/vbb/f1141/
#
# 4: Analyzer & Schematics PRAGMAFIX
# https://forum.gsmhosting.com/vbb/f1142/
#
# 5: 7ICE Team
# Mkey - Modem Unlock Key
# https://forum.gsmhosting.com/vbb/f890/
#
# 6: Avengers Box
# https://forum.gsmhosting.com/vbb/f820/
#
# 7: Chimera Tool
# https://forum.gsmhosting.com/vbb/f898/
#
# 8: Cheetah Tool Products
# https://forum.gsmhosting.com/vbb/f1146/
#
# 9: DC Unlocker
# https://forum.gsmhosting.com/vbb/f1004/
#
# 10: Eagle Eye
# https://forum.gsmhosting.com/vbb/f753/
#
# 11: Easy-Jtag / Easy-Jtag Plus
# The official support section. You can ask here your question and get answer regarding using Easy-Jtag / Easy-Jtag Plus.
# https://forum.gsmhosting.com/vbb/f672/
#
# 12: EFT Dongle
# https://forum.gsmhosting.com/vbb/f1014/
#
# 13: EME Mobile Tool (EMT)
# Official Support Section by EmeGSM Team
# https://forum.gsmhosting.com/vbb/f1107/
#
# 14: FuriousGold
# FuriouS GOLD Support Area | Powered by FuriousTeam
# https://forum.gsmhosting.com/vbb/f272/
#
# 15: GSM Shield Box
# https://forum.gsmhosting.com/vbb/f1087/
#
# 16: GSMServer Products
# Medusa SigmaKey
# Smart-Clip 2
# https://forum.gsmhosting.com/vbb/f372/
#
# 17: HUA Team Products
# HUA Box HDE Tool
# HUA GOLD
# https://forum.gsmhosting.com/vbb/f1021/
#
# 18: HYDRA TOOL
# https://forum.gsmhosting.com/vbb/f1065/
#
# 19: Infinity-Box
# BB5 Easy Service Tool (BEST) Nokia Dongle
# https://forum.gsmhosting.com/vbb/f296/
#
# 20: MFC Team Products
# iBUS Tools For Apple Watch iPOWER X & iREWORK Station
# MFC Dongle (iMFC)
# https://forum.gsmhosting.com/vbb/f935/
#
# 21: NCK Team products
# Mutli Unlocking Tool with Standalone Calculation.
# Avengers Box NCK Box Premium v2
# https://forum.gsmhosting.com/vbb/f691/
#
# 22: Octopus/Octoplus
# Octoplus FRP Tool Octoplus Huawei Tool
# Octopus LG/Octoplus LG Octopus Samsung/Octoplus Samsung
# Octoplus JTAG Octopus/Octoplus Suite
# https://forum.gsmhosting.com/vbb/f594/
#
# 23: Pandora’s box
# Pandora’s box spanish
# https://forum.gsmhosting.com/vbb/f1110/
#
# 24: TFM-Tool
# https://forum.gsmhosting.com/vbb/f1119/
#
# 25: RIFF Box Team
# RIFFBOX
# https://forum.gsmhosting.com/vbb/f543/
#
# 26: Saras Boxes
# Twister , UFS3, Tornado Ufs2 , n-Box
# UFST
# https://forum.gsmhosting.com/vbb/f283/
#
# 27: Ultimate Multi Tool Box
# Multi GSM & CDMA Box
# https://forum.gsmhosting.com/vbb/f970/
#
# 28: UnlockTool
# https://forum.gsmhosting.com/vbb/f1112/
#
# 29: Uni-Android Tool - UAT PRO
# https://forum.gsmhosting.com/vbb/f1019/
#
# 30: Z3X-Team Products
# Pandora’s box by Z3X-Team Z3X-JTAG
# https://forum.gsmhosting.com/vbb/f453/

# %%
DAY = 1
MONTH = 7
YEAR = 2024

KEY_WORDS = ["unlock", "hack", "samsung", "s2", "flip", "fold", "knox"]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Thiết lập chế độ headless cho Chrome
chrome_options = Options()
chrome_options.add_argument("--headless")  # Kích hoạt chế độ headless
# chrome_options.add_argument("--disable-gpu")  # Vô hiệu hóa GPU (giúp chạy ổn định hơn trên Windows)
# chrome_options.add_argument("--no-sandbox")  # Tùy chọn an toàn, đặc biệt khi chạy trong container

# Khởi tạo trình duyệt Chrome với các tùy chọn
wdriver = webdriver.Chrome(options=chrome_options)

# %%
def get_threads_from_link(wdriver, link):
    thread_links = []
    wdriver.get(link['link'])
    print(link['title'])

    rows = wdriver.find_elements(By.XPATH, "//*[contains(@id, 'thread_title')]")
    times = wdriver.find_elements(By.CSS_SELECTOR, "div.smallfont[style*='text-align:right; white-space:nowrap']")

    for i, (row, time) in enumerate(zip(rows, times)):
        title = row.text
        link = row.get_attribute('href')
        creatAt = time.text 

        pattern = r'(\d{2}-\d{2}-\d{4})'
        match = re.search(pattern, time.text)
        if match:
            creatAt = match.group(1)
        else:
            creatAt = None

        if(creatAt != None): 
            thread_links.append({'title': row.text, 'link':link, 'creatAt': creatAt})
        
        # print(f"Row {i+1}: {title} \n{link} \n{creatAt}\n")

    month_str = str(MONTH).zfill(2)
    day_str = str(DAY).zfill(2)
    year_str = str(YEAR)

    deadline = month_str + '-' + day_str + '-' + year_str

    thread_links_by_deadline = [item for item in thread_links if datetime.strptime(item['creatAt'], '%m-%d-%Y') >= datetime.strptime(deadline, '%m-%d-%Y')]

    thread_links_by_keywords = [item for item in thread_links_by_deadline if any(keyword in item['title'].lower() for keyword in KEY_WORDS)]


    for i, thread_link in enumerate(thread_links_by_keywords):
        print(f"Row {i+1}: {thread_link['title']} \n{thread_link['link']} \n{thread_link['creatAt']}\n")

    return thread_links_by_keywords

# %%
total_thread_links = []
for link in (links):
    total_thread_links += get_threads_from_link(wdriver, link)
wdriver.close()

stt = 1
for thread_link in (total_thread_links):
    print(stt) 
    stt+=1
    print(thread_link['title'])
    print(thread_link['link'])
    print(thread_link['creatAt'])
    print()
# Out:
# AMT-dongle
# ART (Android Root Tool)
# Row 1: Samsung M215F Binary 3 FRP Remove via Test Mode method
# https://forum.gsmhosting.com/vbb/f1134/samsung-m215f-binary-3-frp-remove-via-test-mode-method-3321538/
# 07-21-2024
#
# Android Multi Tool (AMT)
# Analyzer & Schematics PRAGMAFIX
# 7ICE Team
# Mkey - Modem Unlock Key
# Avengers Box
# Row 1: Avengers Box / UMTPro Samsung Module v0.4 Released - [14/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/
# 08-14-2024
#
# Row 2: Avengers Box / UMTPro Samsung Tool v0.3 Released - [11/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/
# 08-11-2024
#
# Row 3: Mobicel Legend Pro SimUnlock Done
# https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/
# 07-31-2024
#
# Chimera Tool
# Row 1: ⭐️01/08/2024⭐️Samsung Read Codes solution and Qualcomm Improvements
# https://forum.gsmhosting.com/vbb/f898/01-08-2024-samsung-read-codes-solution-qualcomm-improvements-3322327/
# 08-25-2024
#
# Row 2: ⭐️17/05/2024⭐️Samsung: New Exynos & QComm models + Remove MDM Fix
# https://forum.gsmhosting.com/vbb/f898/17-05-2024-samsung-new-exynos-qcomm-models-remove-mdm-fix-3305137/
# 08-08-2024
#
# Row 3: ⭐️02/05/2024⭐️Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit/Version/Knox
# https://forum.gsmhosting.com/vbb/f898/02-05-2024-exynos-7884-7884b-7885-7904-54-models-no-root-any-bit-version-knox-3302113/
# 08-01-2024
#
# Row 4: chimera tool bug need good support s23 ultra frp fail other tool did it
# https://forum.gsmhosting.com/vbb/f898/chimera-tool-bug-need-good-support-s23-ultra-frp-fail-other-tool-did-3334890/
# 09-09-2024
#
# Row 5: Samsung A042F frp Help
# https://forum.gsmhosting.com/vbb/f898/samsung-a042f-frp-help-3335325/
# 09-09-2024
#
# Row 6: Samsung SM-S901B (S22 5G)(U2) IMEI REPAIR
# https://forum.gsmhosting.com/vbb/f898/samsung-sm-s901b-s22-5g-u2-imei-repair-3211391/
# 09-09-2024
#
# Row 7: samsung A146vl tracephone network unlock
# https://forum.gsmhosting.com/vbb/f898/samsung-a146vl-tracephone-network-unlock-3335276/
# 09-09-2024
#
# Cheetah Tool Products
# Row 1: Successfully Flashed|Repair|Unlocked Phones With Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/
# 09-08-2024
#
# Row 2: All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/
# 09-07-2024
#
# Row 3: Samsung A236E U6 FRP
# https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/
# 09-07-2024
#
# Row 4: Motorola G04 read network unlock code online?
# https://forum.gsmhosting.com/vbb/f1146/motorola-g04-read-network-unlock-code-online-3333554/
# 09-04-2024
#
# DC Unlocker
# Eagle Eye
# Easy-Jtag / Easy-Jtag Plus
# The official support section. You can ask here your question and get answer regarding using Easy-Jtag / Easy-Jtag Plus.
# EFT Dongle
# Row 1: EFT Pro Dongle Update V4.8.1[Added Qualcomm Models for Samsung&MTK Unlock SIM Realme]
# https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-8-1-added-qualcomm-models-samsung-mtk-unlock-sim-realme-3325761/
# 08-16-2024
#
# Row 2: EFT Pro Dongle Update V4.7.9[MTK Update AUTH Server - Xiaomi&Samsung New Model Added]
# https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-7-9-mtk-update-auth-server-xiaomi-samsung-new-model-added-3313468/
# 08-04-2024
#
# Row 3: Nokia 2660 flip TA-1474 Factory Reset
# https://forum.gsmhosting.com/vbb/f1014/nokia-2660-flip-ta-1474-factory-reset-3324963/
# 09-09-2024
#
# EME Mobile Tool (EMT)
# Official Support Section by EmeGSM Team
# FuriousGold
# FuriouS GOLD Support Area | Powered by FuriousTeam
# Row 1: FuriousGold Successfully Unlocked / Repaired / Flashed Phones !!!
# https://forum.gsmhosting.com/vbb/f272/furiousgold-successfully-unlocked-repaired-flashed-phones-661803/
# 07-08-2024
#
# Row 2: ZTE P601 not unlocked
# https://forum.gsmhosting.com/vbb/f272/zte-p601-not-unlocked-3334023/
# 09-03-2024
#
# Row 3: vortex ZG65 Pro unlocked
# https://forum.gsmhosting.com/vbb/f272/vortex-zg65-pro-unlocked-3331214/
# 08-23-2024
#
# Row 4: Movitel M6226 Network locked [SOLVED=UNLOCKED]
# https://forum.gsmhosting.com/vbb/f272/movitel-m6226-network-locked-solved-unlocked-2811611/
# 08-23-2024
#
# Row 5: Vortex HD65 Ultra unlock done by selecting CM62
# https://forum.gsmhosting.com/vbb/f272/vortex-hd65-ultra-unlock-done-selecting-cm62-3329289/
# 08-17-2024
#
# Row 6: How to Root ZTE Z667 in 2024 for unlock?
# https://forum.gsmhosting.com/vbb/f272/how-root-zte-z667-2024-unlock-3328615/
# 08-15-2024
#
# Row 7: zte z5031o unlock problem help
# https://forum.gsmhosting.com/vbb/f272/zte-z5031o-unlock-problem-help-3010892/
# 08-12-2024
#
# GSM Shield Box
# Row 1: [30-08-24] GSMShield Qualcomm 3.6 - Xiaomi Auth, Samsung KG Bypass...
# https://forum.gsmhosting.com/vbb/f1087/30-08-24-gsmshield-qualcomm-3-6-xiaomi-auth-samsung-kg-bypass-3332823/
# 08-30-2024
#
# Row 2: samsung a037 (a03s) frp bypass done
# https://forum.gsmhosting.com/vbb/f1087/samsung-a037-a03s-frp-bypass-done-3332770/
# 08-29-2024
#
# GSMServer Products
# Medusa SigmaKey
# Smart-Clip 2
# HUA Team Products
# HUA Box HDE Tool
# HUA GOLD
# HYDRA TOOL
# Row 1: Samsung Galaxy Tab A8 10.5 [ X 205 ] FRP Lock Removed Done ! BY ! Hydra Tool !!!
# https://forum.gsmhosting.com/vbb/f1065/samsung-galaxy-tab-a8-10-5-x-205-frp-lock-removed-done-hydra-tool-3332643/
# 08-29-2024
#
# Row 2: waitng for samsung exynos update [Answered]
# https://forum.gsmhosting.com/vbb/f1065/waitng-samsung-exynos-update-answered-3331965/
# 08-27-2024
#
# Infinity-Box
# BB5 Easy Service Tool (BEST) Nokia Dongle
# Row 1: Successfully unlocked/repaired phones by Infinity-Box
# https://forum.gsmhosting.com/vbb/f296/successfully-unlocked-repaired-phones-infinity-box-725574/
# 09-09-2024
#
# MFC Team Products
# iBUS Tools For Apple Watch iPOWER X & iREWORK Station
# MFC Dongle (iMFC)
# NCK Team products
# Mutli Unlocking Tool with Standalone Calculation.
# Avengers Box NCK Box Premium v2
# Octopus/Octoplus
# Octoplus FRP Tool Octoplus Huawei Tool
# Octopus LG/Octoplus LG Octopus Samsung/Octoplus Samsung
# Octoplus JTAG Octopus/Octoplus Suite
# Pandora’s box
# Pandora’s box spanish
# TFM-Tool
# Row 1: TFM Tool Pro QC has been added with more Samsung 123 Models/Bit
# https://forum.gsmhosting.com/vbb/f1119/tfm-tool-pro-qc-has-been-added-more-samsung-123-models-bit-3320960/
# 08-08-2024
#
# RIFF Box Team
# RIFFBOX
# Saras Boxes
# Twister , UFS3, Tornado Ufs2 , n-Box
# UFST
# Ultimate Multi Tool Box
# Multi GSM & CDMA Box
# Row 1: [06-01-24] UMTv2/UMTPro UltimateSams v0.7 - Samsung USA FRP in MTP Mode...
# https://forum.gsmhosting.com/vbb/f970/06-01-24-umtv2-umtpro-ultimatesams-v0-7-samsung-usa-frp-mtp-mode-3246575/
# 08-17-2024
#
# Row 2: also return from Samsung service center Samsung a22 5g sucess frp [Success Report] ★
# https://forum.gsmhosting.com/vbb/f970/also-return-samsung-service-center-samsung-a22-5g-sucess-frp-success-report-3335206/
# 09-08-2024
#
# Row 3: Samsung M11 ( SM-M115F ) Binary 5 Android 12 FRP DONE Without Test Point Final Method
# https://forum.gsmhosting.com/vbb/f970/samsung-m11-sm-m115f-binary-5-android-12-frp-done-without-test-point-final-method-3334496/
# 09-08-2024
#
# Row 4: S23 Ultra S918U Lost mode
# https://forum.gsmhosting.com/vbb/f970/s23-ultra-s918u-lost-mode-3328806/
# 09-05-2024
#
# UnlockTool
# Row 1: UnlockTool-2024.09.02.0 Released Update
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-09-02-0-released-update-3333827/
# 09-08-2024
#
# Row 2: ★★★ Post All Successfully Story Repaired Phones by UnlockTool ★★★
# https://forum.gsmhosting.com/vbb/f1112/post-all-successfully-story-repaired-phones-unlocktool-2960341/
# 09-07-2024
#
# Row 3: Guide Video Fix Error Status Code 401 Proxy ! Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/guide-video-fix-error-status-code-401-proxy-unlock-tool-3304882/
# 07-14-2024
#
# Row 4: Test Report | Xiaomi Sidelode Unlock | Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/test-report-xiaomi-sidelode-unlock-unlock-tool-3085099/
# 07-09-2024
#
# Row 5: LG8X ThinQ FRP Done Sucessfully By Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/lg8x-thinq-frp-done-sucessfully-unlock-tool-3334766/
# 09-06-2024
#
# Row 6: A125U Unlock Failed
# https://forum.gsmhosting.com/vbb/f1112/a125u-unlock-failed-3334599/
# 09-06-2024
#
# Uni-Android Tool - UAT PRO
# Row 1: samsung galaxy note 10+ n975f u9 flashing perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-note-10-n975f-u9-flashing-perfect-3332626/
# 08-29-2024
#
# Row 2: SAMSUNG m205f u9 flashing perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-m205f-u9-flashing-perfect-3331248/
# 08-24-2024
#
# Row 3: Samsung Galaxy A24 A245F 4G U3 Frp One Click By UAT PRO
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-a24-a245f-4g-u3-frp-one-click-uat-pro-3285353/
# 08-13-2024
#
# Row 4: SAMSUNG galaxy a235f frp+format edl perfect bit6 by UAT PRO
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-a235f-frp-format-edl-perfect-bit6-uat-pro-3327779/
# 08-12-2024
#
# Row 5: samsung a155f frp
# https://forum.gsmhosting.com/vbb/f1019/samsung-a155f-frp-3324908/
# 08-05-2024
#
# Row 6: UAT PRO V174.02 [1st August 2024] Samsung Update
# https://forum.gsmhosting.com/vbb/f1019/uat-pro-v174-02-1st-august-2024-samsung-update-3323987/
# 08-04-2024
#
# Row 7: Redmi Note 11 NFC spesn Unlock Bootloader Temp [SOLVED]
# https://forum.gsmhosting.com/vbb/f1019/redmi-note-11-nfc-spesn-unlock-bootloader-temp-solved-3323317/
# 08-03-2024
#
# Row 8: UAT PRO V174.01 [27th July 2024] New Samsung Qualcomm Models and New Bit Update
# https://forum.gsmhosting.com/vbb/f1019/uat-pro-v174-01-27th-july-2024-new-samsung-qualcomm-models-new-bit-update-3322854/
# 07-31-2024
#
# Z3X-Team Products
# Pandora’s box by Z3X-Team Z3X-JTAG
# Row 1: Samsung Combination flash files requests ONLY here
# https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/
# 08-06-2024
#
# Row 2: Samsung A750FN relocked again [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a750fn-relocked-again-answered-3335412/
# 09-09-2024
#
# Row 3: sgh x510 help to unlock
# https://forum.gsmhosting.com/vbb/f453/sgh-x510-help-unlock-3334782/
# 09-06-2024
#
# Row 4: SAMSUNG A34 SM-A346E imei repair problem [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a34-sm-a346e-imei-repair-problem-answered-3333452/
# 09-01-2024
#
# Row 5: A125U Unlock Error [Answered]
# https://forum.gsmhosting.com/vbb/f453/a125u-unlock-error-answered-3333273/
# 08-31-2024
#
# Row 6: G991u unlock failed [Answered]
# https://forum.gsmhosting.com/vbb/f453/g991u-unlock-failed-answered-3332806/
# 08-29-2024
#
# Row 7: S23 plus direct unlock possible? [Answered]
# https://forum.gsmhosting.com/vbb/f453/s23-plus-direct-unlock-possible-answered-3332230/
# 08-27-2024
#
# Row 8: samsung a226b u9 network lock [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a226b-u9-network-lock-answered-3332081/
# 08-26-2024
#
# Row 9: Please Update samsungtool with New desing [Answered]
# https://forum.gsmhosting.com/vbb/f453/please-update-samsungtool-new-desing-answered-3331723/
# 08-25-2024
#
# Row 10: samsung a705FN cert patch? [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a705fn-cert-patch-answered-3331219/
# 08-25-2024
#
# Row 11: An important question about Z3X Samsung update and support
# https://forum.gsmhosting.com/vbb/f453/important-question-about-z3x-samsung-update-support-3330256/
# 08-23-2024
#
# Row 12: Samsng n975u unlock error [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsng-n975u-unlock-error-answered-3329583/
# 08-19-2024
#
# Row 13: J330 unlock not done [Answered]
# https://forum.gsmhosting.com/vbb/f453/j330-unlock-not-done-answered-2938791/
# 08-18-2024
#
# 1
# Samsung M215F Binary 3 FRP Remove via Test Mode method
# https://forum.gsmhosting.com/vbb/f1134/samsung-m215f-binary-3-frp-remove-via-test-mode-method-3321538/
# 07-21-2024
#
# 2
# Avengers Box / UMTPro Samsung Module v0.4 Released - [14/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/
# 08-14-2024
#
# 3
# Avengers Box / UMTPro Samsung Tool v0.3 Released - [11/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/
# 08-11-2024
#
# 4
# Mobicel Legend Pro SimUnlock Done
# https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/
# 07-31-2024
#
# 5
# ⭐️01/08/2024⭐️Samsung Read Codes solution and Qualcomm Improvements
# https://forum.gsmhosting.com/vbb/f898/01-08-2024-samsung-read-codes-solution-qualcomm-improvements-3322327/
# 08-25-2024
#
# 6
# ⭐️17/05/2024⭐️Samsung: New Exynos & QComm models + Remove MDM Fix
# https://forum.gsmhosting.com/vbb/f898/17-05-2024-samsung-new-exynos-qcomm-models-remove-mdm-fix-3305137/
# 08-08-2024
#
# 7
# ⭐️02/05/2024⭐️Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit/Version/Knox
# https://forum.gsmhosting.com/vbb/f898/02-05-2024-exynos-7884-7884b-7885-7904-54-models-no-root-any-bit-version-knox-3302113/
# 08-01-2024
#
# 8
# chimera tool bug need good support s23 ultra frp fail other tool did it
# https://forum.gsmhosting.com/vbb/f898/chimera-tool-bug-need-good-support-s23-ultra-frp-fail-other-tool-did-3334890/
# 09-09-2024
#
# 9
# Samsung A042F frp Help
# https://forum.gsmhosting.com/vbb/f898/samsung-a042f-frp-help-3335325/
# 09-09-2024
#
# 10
# Samsung SM-S901B (S22 5G)(U2) IMEI REPAIR
# https://forum.gsmhosting.com/vbb/f898/samsung-sm-s901b-s22-5g-u2-imei-repair-3211391/
# 09-09-2024
#
# 11
# samsung A146vl tracephone network unlock
# https://forum.gsmhosting.com/vbb/f898/samsung-a146vl-tracephone-network-unlock-3335276/
# 09-09-2024
#
# 12
# Successfully Flashed|Repair|Unlocked Phones With Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/
# 09-08-2024
#
# 13
# All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/
# 09-07-2024
#
# 14
# Samsung A236E U6 FRP
# https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/
# 09-07-2024
#
# 15
# Motorola G04 read network unlock code online?
# https://forum.gsmhosting.com/vbb/f1146/motorola-g04-read-network-unlock-code-online-3333554/
# 09-04-2024
#
# 16
# EFT Pro Dongle Update V4.8.1[Added Qualcomm Models for Samsung&MTK Unlock SIM Realme]
# https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-8-1-added-qualcomm-models-samsung-mtk-unlock-sim-realme-3325761/
# 08-16-2024
#
# 17
# EFT Pro Dongle Update V4.7.9[MTK Update AUTH Server - Xiaomi&Samsung New Model Added]
# https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-7-9-mtk-update-auth-server-xiaomi-samsung-new-model-added-3313468/
# 08-04-2024
#
# 18
# Nokia 2660 flip TA-1474 Factory Reset
# https://forum.gsmhosting.com/vbb/f1014/nokia-2660-flip-ta-1474-factory-reset-3324963/
# 09-09-2024
#
# 19
# FuriousGold Successfully Unlocked / Repaired / Flashed Phones !!!
# https://forum.gsmhosting.com/vbb/f272/furiousgold-successfully-unlocked-repaired-flashed-phones-661803/
# 07-08-2024
#
# 20
# ZTE P601 not unlocked
# https://forum.gsmhosting.com/vbb/f272/zte-p601-not-unlocked-3334023/
# 09-03-2024
#
# 21
# vortex ZG65 Pro unlocked
# https://forum.gsmhosting.com/vbb/f272/vortex-zg65-pro-unlocked-3331214/
# 08-23-2024
#
# 22
# Movitel M6226 Network locked [SOLVED=UNLOCKED]
# https://forum.gsmhosting.com/vbb/f272/movitel-m6226-network-locked-solved-unlocked-2811611/
# 08-23-2024
#
# 23
# Vortex HD65 Ultra unlock done by selecting CM62
# https://forum.gsmhosting.com/vbb/f272/vortex-hd65-ultra-unlock-done-selecting-cm62-3329289/
# 08-17-2024
#
# 24
# How to Root ZTE Z667 in 2024 for unlock?
# https://forum.gsmhosting.com/vbb/f272/how-root-zte-z667-2024-unlock-3328615/
# 08-15-2024
#
# 25
# zte z5031o unlock problem help
# https://forum.gsmhosting.com/vbb/f272/zte-z5031o-unlock-problem-help-3010892/
# 08-12-2024
#
# 26
# [30-08-24] GSMShield Qualcomm 3.6 - Xiaomi Auth, Samsung KG Bypass...
# https://forum.gsmhosting.com/vbb/f1087/30-08-24-gsmshield-qualcomm-3-6-xiaomi-auth-samsung-kg-bypass-3332823/
# 08-30-2024
#
# 27
# samsung a037 (a03s) frp bypass done
# https://forum.gsmhosting.com/vbb/f1087/samsung-a037-a03s-frp-bypass-done-3332770/
# 08-29-2024
#
# 28
# Samsung Galaxy Tab A8 10.5 [ X 205 ] FRP Lock Removed Done ! BY ! Hydra Tool !!!
# https://forum.gsmhosting.com/vbb/f1065/samsung-galaxy-tab-a8-10-5-x-205-frp-lock-removed-done-hydra-tool-3332643/
# 08-29-2024
#
# 29
# waitng for samsung exynos update [Answered]
# https://forum.gsmhosting.com/vbb/f1065/waitng-samsung-exynos-update-answered-3331965/
# 08-27-2024
#
# 30
# Successfully unlocked/repaired phones by Infinity-Box
# https://forum.gsmhosting.com/vbb/f296/successfully-unlocked-repaired-phones-infinity-box-725574/
# 09-09-2024
#
# 31
# TFM Tool Pro QC has been added with more Samsung 123 Models/Bit
# https://forum.gsmhosting.com/vbb/f1119/tfm-tool-pro-qc-has-been-added-more-samsung-123-models-bit-3320960/
# 08-08-2024
#
# 32
# [06-01-24] UMTv2/UMTPro UltimateSams v0.7 - Samsung USA FRP in MTP Mode...
# https://forum.gsmhosting.com/vbb/f970/06-01-24-umtv2-umtpro-ultimatesams-v0-7-samsung-usa-frp-mtp-mode-3246575/
# 08-17-2024
#
# 33
# also return from Samsung service center Samsung a22 5g sucess frp [Success Report] ★
# https://forum.gsmhosting.com/vbb/f970/also-return-samsung-service-center-samsung-a22-5g-sucess-frp-success-report-3335206/
# 09-08-2024
#
# 34
# Samsung M11 ( SM-M115F ) Binary 5 Android 12 FRP DONE Without Test Point Final Method
# https://forum.gsmhosting.com/vbb/f970/samsung-m11-sm-m115f-binary-5-android-12-frp-done-without-test-point-final-method-3334496/
# 09-08-2024
#
# 35
# S23 Ultra S918U Lost mode
# https://forum.gsmhosting.com/vbb/f970/s23-ultra-s918u-lost-mode-3328806/
# 09-05-2024
#
# 36
# UnlockTool-2024.09.02.0 Released Update
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-09-02-0-released-update-3333827/
# 09-08-2024
#
# 37
# ★★★ Post All Successfully Story Repaired Phones by UnlockTool ★★★
# https://forum.gsmhosting.com/vbb/f1112/post-all-successfully-story-repaired-phones-unlocktool-2960341/
# 09-07-2024
#
# 38
# Guide Video Fix Error Status Code 401 Proxy ! Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/guide-video-fix-error-status-code-401-proxy-unlock-tool-3304882/
# 07-14-2024
#
# 39
# Test Report | Xiaomi Sidelode Unlock | Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/test-report-xiaomi-sidelode-unlock-unlock-tool-3085099/
# 07-09-2024
#
# 40
# LG8X ThinQ FRP Done Sucessfully By Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/lg8x-thinq-frp-done-sucessfully-unlock-tool-3334766/
# 09-06-2024
#
# 41
# A125U Unlock Failed
# https://forum.gsmhosting.com/vbb/f1112/a125u-unlock-failed-3334599/
# 09-06-2024
#
# 42
# samsung galaxy note 10+ n975f u9 flashing perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-note-10-n975f-u9-flashing-perfect-3332626/
# 08-29-2024
#
# 43
# SAMSUNG m205f u9 flashing perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-m205f-u9-flashing-perfect-3331248/
# 08-24-2024
#
# 44
# Samsung Galaxy A24 A245F 4G U3 Frp One Click By UAT PRO
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-a24-a245f-4g-u3-frp-one-click-uat-pro-3285353/
# 08-13-2024
#
# 45
# SAMSUNG galaxy a235f frp+format edl perfect bit6 by UAT PRO
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-a235f-frp-format-edl-perfect-bit6-uat-pro-3327779/
# 08-12-2024
#
# 46
# samsung a155f frp
# https://forum.gsmhosting.com/vbb/f1019/samsung-a155f-frp-3324908/
# 08-05-2024
#
# 47
# UAT PRO V174.02 [1st August 2024] Samsung Update
# https://forum.gsmhosting.com/vbb/f1019/uat-pro-v174-02-1st-august-2024-samsung-update-3323987/
# 08-04-2024
#
# 48
# Redmi Note 11 NFC spesn Unlock Bootloader Temp [SOLVED]
# https://forum.gsmhosting.com/vbb/f1019/redmi-note-11-nfc-spesn-unlock-bootloader-temp-solved-3323317/
# 08-03-2024
#
# 49
# UAT PRO V174.01 [27th July 2024] New Samsung Qualcomm Models and New Bit Update
# https://forum.gsmhosting.com/vbb/f1019/uat-pro-v174-01-27th-july-2024-new-samsung-qualcomm-models-new-bit-update-3322854/
# 07-31-2024
#
# 50
# Samsung Combination flash files requests ONLY here
# https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/
# 08-06-2024
#
# 51
# Samsung A750FN relocked again [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a750fn-relocked-again-answered-3335412/
# 09-09-2024
#
# 52
# sgh x510 help to unlock
# https://forum.gsmhosting.com/vbb/f453/sgh-x510-help-unlock-3334782/
# 09-06-2024
#
# 53
# SAMSUNG A34 SM-A346E imei repair problem [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a34-sm-a346e-imei-repair-problem-answered-3333452/
# 09-01-2024
#
# 54
# A125U Unlock Error [Answered]
# https://forum.gsmhosting.com/vbb/f453/a125u-unlock-error-answered-3333273/
# 08-31-2024
#
# 55
# G991u unlock failed [Answered]
# https://forum.gsmhosting.com/vbb/f453/g991u-unlock-failed-answered-3332806/
# 08-29-2024
#
# 56
# S23 plus direct unlock possible? [Answered]
# https://forum.gsmhosting.com/vbb/f453/s23-plus-direct-unlock-possible-answered-3332230/
# 08-27-2024
#
# 57
# samsung a226b u9 network lock [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a226b-u9-network-lock-answered-3332081/
# 08-26-2024
#
# 58
# Please Update samsungtool with New desing [Answered]
# https://forum.gsmhosting.com/vbb/f453/please-update-samsungtool-new-desing-answered-3331723/
# 08-25-2024
#
# 59
# samsung a705FN cert patch? [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a705fn-cert-patch-answered-3331219/
# 08-25-2024
#
# 60
# An important question about Z3X Samsung update and support
# https://forum.gsmhosting.com/vbb/f453/important-question-about-z3x-samsung-update-support-3330256/
# 08-23-2024
#
# 61
# Samsng n975u unlock error [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsng-n975u-unlock-error-answered-3329583/
# 08-19-2024
#
# 62
# J330 unlock not done [Answered]
# https://forum.gsmhosting.com/vbb/f453/j330-unlock-not-done-answered-2938791/
# 08-18-2024

# %%
def getDataByLink(webdriver,url):
    webdriver.get(url)
    
    # lay the div co id la edit...
    edit_divs = driver.find_elements(By.CSS_SELECTOR, "table[id^='post']:nth-of-type(-n+5)")
    list_answers = []
    for i, div in enumerate(edit_divs):
        div_id = div.get_attribute("id")    #ex: edit14872555
        id = div_id[4:]                     #ex: 14872555

        #title
        # strong_tags = div.find_elements(By.TAG_NAME, "strong")
        # title = strong_tags[0].text
        # print('Title: ' + title)

        #content
        content = div.find_element(By.ID, f"post_message_{id}").text
        list_answers.append(content)
    return list_answers

# %%
def showAnswers(list_answers, id):
    for i, answer in enumerate(list_answers):
        print(f"Answer {i+1}: {answer}\n")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Thiết lập chế độ headless cho Chrome
chrome_options = Options()
chrome_options.add_argument("--headless")  # Kích hoạt chế độ headless
# chrome_options.add_argument("--disable-gpu")  # Vô hiệu hóa GPU (giúp chạy ổn định hơn trên Windows)
# chrome_options.add_argument("--no-sandbox")  # Tùy chọn an toàn, đặc biệt khi chạy trong container

# Khởi tạo trình duyệt Chrome với các tùy chọn
driver = webdriver.Chrome(options=chrome_options)

# %%
list_answers = []
for i, thread_link in enumerate(total_thread_links):
    print(f"Thread {i}: {thread_link['link']}")
    list_answers.append(getDataByLink(driver, thread_link['link']))
driver.quit()
# Out:
# Thread 0: https://forum.gsmhosting.com/vbb/f1134/samsung-m215f-binary-3-frp-remove-via-test-mode-method-3321538/
# Thread 1: https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/
# Thread 2: https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/
# Thread 3: https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/
# Thread 4: https://forum.gsmhosting.com/vbb/f898/01-08-2024-samsung-read-codes-solution-qualcomm-improvements-3322327/
# Thread 5: https://forum.gsmhosting.com/vbb/f898/17-05-2024-samsung-new-exynos-qcomm-models-remove-mdm-fix-3305137/
# Thread 6: https://forum.gsmhosting.com/vbb/f898/02-05-2024-exynos-7884-7884b-7885-7904-54-models-no-root-any-bit-version-knox-3302113/
# Thread 7: https://forum.gsmhosting.com/vbb/f898/chimera-tool-bug-need-good-support-s23-ultra-frp-fail-other-tool-did-3334890/
# Thread 8: https://forum.gsmhosting.com/vbb/f898/samsung-a042f-frp-help-3335325/
# Thread 9: https://forum.gsmhosting.com/vbb/f898/samsung-sm-s901b-s22-5g-u2-imei-repair-3211391/
# Thread 10: https://forum.gsmhosting.com/vbb/f898/samsung-a146vl-tracephone-network-unlock-3335276/
# Thread 11: https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/
# Thread 12: https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/
# Thread 13: https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/
# Thread 14: https://forum.gsmhosting.com/vbb/f1146/motorola-g04-read-network-unlock-code-online-3333554/
# Thread 15: https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-8-1-added-qualcomm-models-samsung-mtk-unlock-sim-realme-3325761/
# Thread 16: https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-7-9-mtk-update-auth-server-xiaomi-samsung-new-model-added-3313468/
# Thread 17: https://forum.gsmhosting.com/vbb/f1014/nokia-2660-flip-ta-1474-factory-reset-3324963/
# Thread 18: https://forum.gsmhosting.com/vbb/f272/furiousgold-successfully-unlocked-repaired-flashed-phones-661803/
# Thread 19: https://forum.gsmhosting.com/vbb/f272/zte-p601-not-unlocked-3334023/
# Thread 20: https://forum.gsmhosting.com/vbb/f272/vortex-zg65-pro-unlocked-3331214/
# Thread 21: https://forum.gsmhosting.com/vbb/f272/movitel-m6226-network-locked-solved-unlocked-2811611/
# Thread 22: https://forum.gsmhosting.com/vbb/f272/vortex-hd65-ultra-unlock-done-selecting-cm62-3329289/
# Thread 23: https://forum.gsmhosting.com/vbb/f272/how-root-zte-z667-2024-unlock-3328615/
# Thread 24: https://forum.gsmhosting.com/vbb/f272/zte-z5031o-unlock-problem-help-3010892/
# Thread 25: https://forum.gsmhosting.com/vbb/f1087/30-08-24-gsmshield-qualcomm-3-6-xiaomi-auth-samsung-kg-bypass-3332823/
# Thread 26: https://forum.gsmhosting.com/vbb/f1087/samsung-a037-a03s-frp-bypass-done-3332770/
# Thread 27: https://forum.gsmhosting.com/vbb/f1065/samsung-galaxy-tab-a8-10-5-x-205-frp-lock-removed-done-hydra-tool-3332643/
# Thread 28: https://forum.gsmhosting.com/vbb/f1065/waitng-samsung-exynos-update-answered-3331965/
# Thread 29: https://forum.gsmhosting.com/vbb/f296/successfully-unlocked-repaired-phones-infinity-box-725574/
# Thread 30: https://forum.gsmhosting.com/vbb/f1119/tfm-tool-pro-qc-has-been-added-more-samsung-123-models-bit-3320960/
# Thread 31: https://forum.gsmhosting.com/vbb/f970/06-01-24-umtv2-umtpro-ultimatesams-v0-7-samsung-usa-frp-mtp-mode-3246575/
# Thread 32: https://forum.gsmhosting.com/vbb/f970/also-return-samsung-service-center-samsung-a22-5g-sucess-frp-success-report-3335206/
# Thread 33: https://forum.gsmhosting.com/vbb/f970/samsung-m11-sm-m115f-binary-5-android-12-frp-done-without-test-point-final-method-3334496/
# Thread 34: https://forum.gsmhosting.com/vbb/f970/s23-ultra-s918u-lost-mode-3328806/
# Thread 35: https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-09-02-0-released-update-3333827/
# Thread 36: https://forum.gsmhosting.com/vbb/f1112/post-all-successfully-story-repaired-phones-unlocktool-2960341/
# Thread 37: https://forum.gsmhosting.com/vbb/f1112/guide-video-fix-error-status-code-401-proxy-unlock-tool-3304882/
# Thread 38: https://forum.gsmhosting.com/vbb/f1112/test-report-xiaomi-sidelode-unlock-unlock-tool-3085099/
# Thread 39: https://forum.gsmhosting.com/vbb/f1112/lg8x-thinq-frp-done-sucessfully-unlock-tool-3334766/
# Thread 40: https://forum.gsmhosting.com/vbb/f1112/a125u-unlock-failed-3334599/
# Thread 41: https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-note-10-n975f-u9-flashing-perfect-3332626/
# Thread 42: https://forum.gsmhosting.com/vbb/f1019/samsung-m205f-u9-flashing-perfect-3331248/
# Thread 43: https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-a24-a245f-4g-u3-frp-one-click-uat-pro-3285353/
# Thread 44: https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-a235f-frp-format-edl-perfect-bit6-uat-pro-3327779/
# Thread 45: https://forum.gsmhosting.com/vbb/f1019/samsung-a155f-frp-3324908/
# Thread 46: https://forum.gsmhosting.com/vbb/f1019/uat-pro-v174-02-1st-august-2024-samsung-update-3323987/
# Thread 47: https://forum.gsmhosting.com/vbb/f1019/redmi-note-11-nfc-spesn-unlock-bootloader-temp-solved-3323317/
# Thread 48: https://forum.gsmhosting.com/vbb/f1019/uat-pro-v174-01-27th-july-2024-new-samsung-qualcomm-models-new-bit-update-3322854/
# Thread 49: https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/
# Thread 50: https://forum.gsmhosting.com/vbb/f453/samsung-a750fn-relocked-again-answered-3335412/
# Thread 51: https://forum.gsmhosting.com/vbb/f453/sgh-x510-help-unlock-3334782/
# Thread 52: https://forum.gsmhosting.com/vbb/f453/samsung-a34-sm-a346e-imei-repair-problem-answered-3333452/
# Thread 53: https://forum.gsmhosting.com/vbb/f453/a125u-unlock-error-answered-3333273/
# Thread 54: https://forum.gsmhosting.com/vbb/f453/g991u-unlock-failed-answered-3332806/
# Thread 55: https://forum.gsmhosting.com/vbb/f453/s23-plus-direct-unlock-possible-answered-3332230/
# Thread 56: https://forum.gsmhosting.com/vbb/f453/samsung-a226b-u9-network-lock-answered-3332081/
# Thread 57: https://forum.gsmhosting.com/vbb/f453/please-update-samsungtool-new-desing-answered-3331723/
# Thread 58: https://forum.gsmhosting.com/vbb/f453/samsung-a705fn-cert-patch-answered-3331219/
# Thread 59: https://forum.gsmhosting.com/vbb/f453/important-question-about-z3x-samsung-update-support-3330256/
# Thread 60: https://forum.gsmhosting.com/vbb/f453/samsng-n975u-unlock-error-answered-3329583/
# Thread 61: https://forum.gsmhosting.com/vbb/f453/j330-unlock-not-done-answered-2938791/

# %% [markdown]
# ### export data .csv

# %%
# export data .csv
MIN_WORDS = 30
import csv
import pandas as pd

# set features
columns = ['Type', 'Link',  'Published', 'Title', 'Content']
data = []

for i, thread_link in enumerate(total_thread_links):
    row = ['youtube', thread_link["link"], thread_link["title"], thread_link["creatAt"], ''.join(list_answers[i][0:5])]
    if len(list_answers[i][0]) >= MIN_WORDS:
        data.append(row)

# %%
import pandas as pd
import os
from datetime import datetime
today = datetime.today().date()

df = pd.DataFrame(data, columns=columns)

file_path = f'../output/output_{today}.xlsx'
if os.path.exists(file_path):
    with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='new') as writer:
        df.to_excel(writer, sheet_name=f'gsm_{today}', index=False)
else:
    with pd.ExcelWriter(file_path, engine='openpyxl', mode='w') as writer:
        df.to_excel(writer, sheet_name=f'gsm_{today}', index=False)

# %%
#print data
for i, thread_link in enumerate(total_thread_links):
    row = [thread_link["link"], thread_link["title"], thread_link["creatAt"]] + list_answers[i][0:5]
    print(i+1)
    if len(list_answers[i][0]) >= MIN_WORDS:
        print(f'Title: {thread_link["title"]}')
        print(f'Link: {thread_link["link"]}')
        print(f'CreatAt:  {thread_link["creatAt"]}')
    
    print (''.join(list_answers[i][0:5]))
    print("======================================================================")
# Out:
# 1
#
# ======================================================================
# 2
# Title: Avengers Box / UMTPro Samsung Module v0.4 Released - [14/08/2024]
# Link: https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/
# CreatAt:  08-14-2024
# Added Samsung models
# Galaxy A52 SM-A525M BIT6
# Galaxy Z Flip6 5G SM-F741B BIT1
# Galaxy Z Fold 5G SM-F946B BIT3
# Galaxy S21 FE 5G SM-G990U BITC
# Galaxy S21 FE SM-G990U2 BITA
# Galaxy S22 Ultra 5G SM-S908E BITA
# Galaxy S23 Ultra 5G SM-S918B BIT6
# Galaxy S24 Ultra 5G SM-S928B BIT3
# Galaxy S24 Ultra 5G SM-S928N BIT2
# Galaxy A05s SM-A057F BIT3
# Galaxy S21 FE 5G SM-G990B2 BIT7
# Galaxy S21 5G SM-G991U BIT10
# Galaxy M23(Buddy 2) 5G 2022 SM-M236L BIT6
# Galaxy M23(Buddy 2) 5G 2022 SM-M236L BIT3
# Galaxy M23(Buddy 2) 5G 2022 SM-M236L BIT4
# Galaxy M23(Buddy 2) 5G 2022 SM-M236L BIT5
# Galaxy M23(Buddy 2) 5G 2022 SM-M236L
# Galaxy Note 10+ SM-N975U BIT8
# Galaxy S22 Ultra 5G SM-S908U BIT6
# Galaxy Tab A7 10.4 (2020) SM-T500 BIT8
# Galaxy J6 Plus SM-J610G BIT3
# Galaxy M01 SM-M015G BIT5
# Galaxy M11 SM-M115F BIT3
#
# - Read info in edl normal & download mode,
# - Reset frp in edl mode,
# - Reset userdata in edl mode.
#
# Added Flashing in download mode using normal tar.md5 firmware.
# Added read info in download mode (display partitions info).
# Added read phone info and frp state info in normal mode.
#
#
#
# Still Don’t have NCK ?
#
# Do you have UMT?
#
# Now you can activation NCK Box Premium v2 on UMT Cards
# so you can use it with out shipping costs without limits
#
# Official Website:
#
# Avengers Box
# UMT Pro
#
#
# Official Shop:
# https://fastunlocking.com/shop/en/
#
#
# Payments by
# Credit Card via Stripe gateway
# Paypal
# Credit Card via Paypal
# Credit Card via Google Pay
# Credit Card via Apple Pay
#
#
#
# Download From Support Area
#
#
# OR
#
# https://drive.google.com/file/d/1U6D...usp=drive_link
#
# Password for Zip:
#
# NckTeam
# ======================================================================
# 3
# Title: Avengers Box / UMTPro Samsung Tool v0.3 Released - [11/08/2024]
# Link: https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/
# CreatAt:  08-11-2024
# Samsung
# Galaxy A05s - SM-A05F (Bit 4)
# Galaxy Z Flip4 - SM-F721U (U/U1/W) (BIT6)
# Galaxy Z Flip5 - SM-F731B_DS (BIT2)
# Galaxy Z Flip5 - SM-F731U1 (U/U1/W) (BIT4)
# Galaxy Z Fold5 - SM-F946B_DS (BIT2)
# Galaxy Z Fold5 - SM-F946U (U/U1/W) (BIT4)
# Galaxy Z Fold 6 - SM-F956U (U/U1/W) (BIT1)
# Galaxy S23 - SM-S911U (U/U1/W) (BIT4)
# Galaxy S23+ - SM-S916B_DS (BIT5)
# Galaxy S23 - SM-S916U (U/U1/W) (BIT4)
# Galaxy S23 Ultra SM-S918U (U/U1/W) (BIT4)
# Galaxy S24 - SM-S921U (U/U1/W) (BIT3)
# Galaxy S24+ - SM-S926U (U/U1/W) (BIT3)
# Galaxy S24 Ultra - SM-S928U (U/U1/W) (BIT3)
# Galaxy A71 SM-A716U/W Bit B
# Galaxy A01 (SM-A015M) BIT5
# Galaxy A11 (SM-A115M) BIT3
# Galaxy A23 (SM-A235M) BIT4
# Galaxy S22 Ultra 5G (SM-S908E) BIT8
# Galaxy S10 Lite SM-G770F BIT9
#
# Reset FRP in EDL mode
# Format Userdata in FRP mode
#
# Fixed reset Samsung MTK FRP in download mode mode.
# Added Read phone info and partitions info on download mode.
# Bug fixes.
#
#
# Official Website:
#
# Avengers Box
# UMT Pro
#
#
# Official Shop:
# https://fastunlocking.com/shop/en/
#
#
# Payments by
# Credit Card via Stripe gateway
# Paypal
# Credit Card via Paypal
# Credit Card via Google Pay
# Credit Card via Apple Pay
#
#
#
# Download From Support Area
#
#
# OR
#
# https://drive.google.com/file/d/1RB8...usp=drive_link
#
# Password for Zip:
#
# NckTeamUmt is allway good update but samsung exynos frp NOT updete please... exynos updete...thx..
#
#
#
# Bro...
#
# Zishanm...Fixed reset Samsung MTK FRP in download mode mode.
#
# is there new way to reset may security patch?Add samsung A715f Bit BAlways good update UMT team
# ======================================================================
# 4
# Title: Mobicel Legend Pro SimUnlock Done
# Link: https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/
# CreatAt:  07-31-2024
# Code:
# SELECTED: SC9863A
# ACTION:  SimUnlock
# Start Detect phone.
# Phone must be off(you can service this phone without battery also).
# Long press "VOL -"+ "VOL +" key while inserting usb cable.
# Keep key untill boot complete.
# Detected: SPRD U2S Diag (COM5)
# Sending payload, keep boot key untill loader start.
# Exploiting phone.....
# Sending preloader 1
# Sending preloader 2
# Sending FDL 1.....
# Sending FDL 2.....
# New flash metod detected.
# [5f] 440A23 [5e] 9188D8
# UID: A0XS0B_6_17_88
# FileSystem: EMMC
# Read partition info is supported by loader.
# ***************
# [S]Manufacturer: Mobicel
# [S]Brand: Mobicel
# [S]Device: Legend_Pro_LTE
# [S]Model: Legend Pro LTE
# Build ID: RP1A.201005.001
# CPU arhitecture: armeabi-v7a
# Build product name: s9863a1h10_go_32b
# Build description: Mobicel_Legend_Pro_LTE_DS_T_L_V01_20220614 11 RP1A.201005.001 25442 release-keys
# Board: Legend_Pro_LTE
# Build Id: RP1A.201005.001
# Android Release: 11
# Android Version: RP1A.201005.001 release-keys
# Security patch: 2022-05-05
# CPU NAME: SC9863A
# SN: 5064041265071905
# Found [l_fixnv1_a] [l_fixnv1_a] Size to download: 2 MB
# Reading: l_fixnv1_a 200000
# Length: 100000 chk: 6253 calculated chk: 6252 calculated chk_32: 6253
# IMEI 1: 352594560613172
# IMEI 2: 352594560613180
# IMEI 3: 867400020316638
# IMEI 4: 867400020316646
# Simlock Type: 3
#
# Simlock Status:
# SIMLOCK: ACTIVE
# NETWORK SUBNET: INACTIVE
# SP LOCK: INACTIVE
# CORPORATE: INACTIVE
# USER LOCK: INACTIVE
# [3]Simlock Type: 0  0
# [352594560613172] Unlock code: 87316483
# [352594560613180] Unlock code: 87316493
# Warning, this is factory key, some opperators can modify factory key.
# Reading: prodnv
# Reading: miscdata
# Reading: l_fixnv1_a
# Reading: l_fixnv2_a
# Reading: l_fixnv1_b
# Reading: l_fixnv2_b
# Backup saved to: C:\Avengers\spreadtrum_module\spreadtrum_module_backup_folder\flashmode_security_backup\SC9863A_Mobicel_RP1A_201005_001_release-keys_352594560613172_352594560613180_l_fixnv1_a_nvram_backup.tar
# Phone have empty sign array, can be empty efuse or erased nv.
# Start write unlock, wait...
# [l_runtimenv1]Format OK.
# [l_runtimenv2]Format OK.
# Write[0]
# Write[1]
# [can take 0-10 sec]Wait untill phone restart.
# Exe version: Avengers Unisoc Module 2.3.1
# Log saved:
# C:\Avengers\spreadtrum_module\spreadtrum_module_backup_folder\Saved_Logs\Mobicel_RP1A_201005_001_release-keys_352594560613172_352594560613180_sim_unlock_phone.txt
# Total Time: 00:01:29
# Done.
# ======================================================================
# 5
# Title: ⭐️01/08/2024⭐️Samsung Read Codes solution and Qualcomm Improvements
# Link: https://forum.gsmhosting.com/vbb/f898/01-08-2024-samsung-read-codes-solution-qualcomm-improvements-3322327/
# CreatAt:  08-25-2024
# Samsung Read Codes solution and Qualcomm Improvements
#
# Enhanced Samsung solution with updated Read Codes procedure for 150 Samsung models
#
# We are excited to announce that the updated Read Codes procedure is now compatible with more firmware versions than ever(*). This method does not require root access or device disassembly, making it more convenient for you. Please note that the device must have a Knox warranty status of 0, as the procedure will not work if the warranty is voided.
#
# The updated Read Codes procedure is supported for the following models:
# Samsung Galaxy A04s (SM-A047F, SM-A047M)
# Samsung Galaxy A10 (SM-A105F, SM-A105FN, SM-A105G, SM-A105M)
# Samsung Galaxy A12 Nacho (SM-A127F, SM-A127M)
# Samsung Galaxy A13 (SM-A135F, SM-A135M)
# Samsung Galaxy A14 (SM-A145F, SM-A145M, SM-A145FB, SM-A145MB)
# Samsung Galaxy A2 Core (SM-A260F, SM-A260G)
# Samsung Galaxy A20 (SM-A205F, SM-A205FN, SM-A205G, SM-A205GN, SM-A205YN)
# Samsung Galaxy A20e (SM-A202F)
# Samsung Galaxy A21s (SM-A217F, SM-A217M)
# Samsung Galaxy A3 (2016) (SM-A310F, SM-A310M, SM-A310Y)
# Samsung Galaxy A3 (2017) (SM-A320F, SM-A320FL, SM-A320Y)
# Samsung Galaxy A30 (SM-A305F, SM-A305FN, SM-A305G, SM-A305GN, SM-A305GT, SM-A305YN)
# Samsung Galaxy A30s (SM-A307FN, SM-A307G, SM-A307GN, SM-A307GT)
# Samsung Galaxy A33 5G (SM-A336B, SM-A336E, SM-A336M)
# Samsung Galaxy A40 (SM-A405F, SM-A405FM, SM-A405FN)
# Samsung Galaxy A50 (SM-A505F, SM-A505FM, SM-A505FN, SM-A505G, SM-A505GN, SM-A505GT, SM-A505YN)
# Samsung Galaxy A50s (SM-A507FN)
# Samsung Galaxy A51 (SM-A515F)
# Samsung Galaxy A51 5G (SM-A516B)
# Samsung Galaxy A53 5G (SM-A536B, SM-A536E)
# Samsung Galaxy A5 (2016) (SM-A510F, SM-A510M, SM-A510Y)
# Samsung Galaxy A5 (2017) (SM-A520F)
# Samsung Galaxy A6 (2018) (SM-A600F, SM-A600FN, SM-A600G, SM-A600GN)
# Samsung Galaxy A7 (2016) (SM-A710F, SM-A710M, SM-A710Y)
# Samsung Galaxy A7 (2017) (SM-A720F)
# Samsung Galaxy A7 (2018) (SM-A750F, SM-A750FN, SM-A750G, SM-A750GN)
# Samsung Galaxy A71 5G (SM-A716B)
# Samsung Galaxy A8 (2018) (SM-A530F)
# Samsung Galaxy A8+ (2018) (SM-A730F)
# Samsung Galaxy F12 (SM-F127G)
# Samsung Galaxy F13 (SM-E135F)
# Samsung Galaxy F34 (SM-E346B)
# Samsung Galaxy F41 (SM-F415F)
# Samsung Galaxy F62 (SM-E625F)
# Samsung Galaxy J2 Dash (SM-J260A, SM-J260AZ, SM-J260F, SM-J260G, SM-J260M)
# Samsung Galaxy J3 (2017) (SM-J330F, SM-J330FN, SM-J330G, SM-J330L)
# Samsung Galaxy J3 Emerge (SM-J327A, SM-J327AZ)
# Samsung Galaxy J4 (SM-J400F, SM-J400G, SM-J400M)
# Samsung Galaxy J5 (2017) (SM-J530F, SM-J530FM, SM-J530G, SM-J530GM, SM-J530Y, SM-J530YM)
# Samsung Galaxy J5 Prime (SM-G570F, SM-G570M, SM-G570Y)
# Samsung Galaxy J7 Prime (SM-G610F, SM-G610M, SM-G610Y)
# Samsung Galaxy J7 Prime 2 (SM-G611F, SM-G611FF, SM-G611M, SM-G611MT)
# Samsung Galaxy M12 (SM-M127F, SM-M127G)
# Samsung Galaxy M13 (SM-M135F, SM-M135FU, SM-M135M)
# Samsung Galaxy M33 5G (SM-M336B, SM-M336BU)
# Samsung Galaxy M34 5G (SM-M346B, SM-M346B1, SM-M346B2)
# Samsung Galaxy S10 (SM-G973F)
# Samsung Galaxy S10+ (SM-G975F)
# Samsung Galaxy S10 5G (SM-G977B)
# Samsung Galaxy S10e (SM-G970F)
# Samsung Galaxy S20 (SM-G980F)
# Samsung Galaxy S20 5G (SM-G981B)
# Samsung Galaxy S20 FE (SM-G780F)
# Samsung Galaxy S20+ (SM-G985F)
# Samsung Galaxy S20+ 5G (SM-G986B)
# Samsung Galaxy S20 Ultra 5G (SM-G988B)
# Samsung Galaxy S21 5G (SM-G991B)
# Samsung Galaxy S21 FE 5G (SM-G990E)
# Samsung Galaxy S21 Ultra 5G (SM-G998B)
# Samsung Galaxy S21+ 5G (SM-G996B)
# Samsung Galaxy S7 (SM-G930F)
# Samsung Galaxy S7 Edge (SM-G935F)
# Samsung Galaxy S8 (SM-G950F)
# Samsung Galaxy S8+ (SM-G955F)
# Samsung Galaxy S9 (SM-G960F)
# Samsung Galaxy S9+ (SM-G965F)
# Samsung Galaxy XCover 4 (SM-G390F, SM-G390Y)
# Samsung Galaxy XCover 4s (SM-G398FN)
# Samsung Galaxy XCover 5 (SM-G525F)
# Samsung Galaxy XCover FieldPro (SM-G889F, SM-G889G, SM-G889YB)
# Samsung Galaxy XCover Pro (SM-G715FN)
#
# Samsung Qualcomm Improvements
#
# More new programmers have arrived for Samsung Qualcomm.
#
# The following models and BIT versions are supported:
# Samsung Galaxy Z Fold 5 (SM-F946B) BIT3
# Samsung Galaxy Z Flip 5 (SM-F731B) BIT3
# Samsung Galaxy S23 Ultra (SM-S918U/U1/W) BIT4
# Samsung Galaxy Z Flip4 (SM-F721U/U1/W) BIT6
# Samsung Galaxy A23 5G (SM-A236U/U1/W) BIT6
# Samsung Galaxy Note 20 5G (SM-N981U/U1/W) BIT7
# Samsung Galaxy Note 20 Ultra 5G (SM-N986U/U1/W) BIT7
# Samsung Galaxy S21 Ultra 5G (SM-G998U/U1/W) BITB
# Samsung Galaxy S22 5G (SM-S901U/U1/W) BIT6
#
# Huawei Qualcomm Improvements
#
# More new programmers have arrived for Huawei Qualcomm.
#
# The following models are supported:
# Honor 80 (ANN-AN00)
# Huawei Enjoy 60x (STG-AL00)
# Huawei Mate 50 (CET-AL00)
# Huawei Mate 50 RS (DCO-AL00)
# Huawei Nova 10 (NCO-AL00)
# Huawei Nova 10 Pro (GLA-AL00)
# Huawei Nova 10 SE (BNE-AL00)
# Huawei Nova 11 (FOA-AL00)
# Huawei Nova 11 Pro (GOA-AL80)
# Huawei P60 (LNA-AL00)
# Huawei P60 Art (MNA-AL00)
#
# *: The solution is compatible with most firmware versions up to Android 13, as well as most Android 14 firmware versions with security patches dated August 2023 and earlier.
#
# Software version: 40.18.1013
# Release date: 01 august 2024
#
#
#
#
#
#
# Visit our Webshop: https://chimeratool.com/shop
# Join our Telegram: https://t.me/chimeratool_offical
# Like us on Facebook: https://www.facebook.com/chimeratool
# Read our Help & Documentation: https://chimeratool.com/docs
# Get Support: https://chimeratool.com/contact
#
# GsmEasy Distributor: http://www.imei.us
# GsmServer Distributor: http://www.gsmserver.comgood ubdates
# add samsung qualcomm supported BITS for edl operations
# in website supported models lists
# it will wery useful for check supported or notAdd Samsung A736b u8 Chimera team..a057g frp......................That's what we called WOW update!!
# Go ahead, Chimera team; you're the best, You really deserve every penny we paid for.
# ======================================================================
# 6
# Title: ⭐️17/05/2024⭐️Samsung: New Exynos & QComm models + Remove MDM Fix
# Link: https://forum.gsmhosting.com/vbb/f898/17-05-2024-samsung-new-exynos-qcomm-models-remove-mdm-fix-3305137/
# CreatAt:  08-08-2024
# Samsung: New Exynos & QComm models + Remove MDM Fix
#
# More new programmers have arrived for Samsung Qualcomm. The following models and BIT versions are supported:
# Samsung Galaxy A02s (SM-A025M BIT8)
# Samsung Galaxy A20s 2019 (SM-A207F BIT5)
# Samsung Galaxy A20s 2019 (SM-A207M BIT4)
# Samsung Galaxy A23 (SM-A235M BIT5)
# Samsung Galaxy S23 Ultra 5G (SM-S918B BIT4)
# Samsung Galaxy S22 Ultra 5G (SM-S908E BIT8)
#
# Samsung Exynos
#
# The following new models were added to be supported from EUB mode:
# Samsung Galaxy A54 5G (SCG21)
# Samsung Galaxy Tab S9 FE Plus 5G (SCT22)
# Samsung Galaxy Tab A 8.4 2020 (SM-T307U)
#
# Available procedures: Restore / Store Backup, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Knoxguard Remove, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset (*), Unlock / Relock Bootloader (**) For more detailed information, please visit our Supported models page.
#
# *: if Read Codes is not available on your device, please try Network Factory Reset (if the procedure button is visible) to achieve the same functionality. There are devices where none is available.
# **: This is a beta feature, and it doesn't work on 100% of the devices, but our team is working on fully supporting the procedure.
#
#
# Bugfixes
# Fixed a bug in Remove MDM procedure which could cause application crashes for Samsung Exynos devices
#
# Software version: 39.42.1216
# Release date: 17 may 2024
#
#
#
#
# Visit our Webshop: https://chimeratool.com/shop
# Join our Telegram: https://t.me/chimeratool_offical
# Like us on Facebook: https://www.facebook.com/chimeratool
# Read our Help & Documentation: https://chimeratool.com/docs
# Get Support: https://chimeratool.com/contact
#
# GsmEasy Distributor: http://www.imei.us
# GsmServer Distributor: http://www.gsmserver.comYou make life easy for us King of Exynos
#
# Best Regards | YobaThanks for the useful and fast updates Samsung A12 (A127) please added Switch to EUB procedure ( from ODIN mode)after frp remove its struck eub mode, how to exit eub modeDear User,
#
#
#
#
# Please run a Repair Boot/ Unbrick on the device and it will boot into normal mode.
#
#
# Regards,
# ChimeraTeam
#
#
#
# Quote:
# Originally Posted by cellcare prasad
# after frp remove its struck eub mode, how to exit eub mode
# ======================================================================
# 7
# Title: ⭐️02/05/2024⭐️Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit/Version/Knox
# Link: https://forum.gsmhosting.com/vbb/f898/02-05-2024-exynos-7884-7884b-7885-7904-54-models-no-root-any-bit-version-knox-3302113/
# CreatAt:  08-01-2024
# New Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit, Any Version, Any Knox
#
#
#
# We haven't finished yet! This time we're thrilled to introduce support for
# Exynos 7884
# Exynos 7884B
# Exynos 7885
# Exynos 7904
#
# This solution is similar to our previous Exynos update in that it uses the EUB mode* to communicate with the device.
#
#
# The following devices are supported:
# Samsung Galaxy A10e (SM-A102N, SM-A102U, SM-A102U1, SM-A102W, SM-S102DL)
# Samsung Galaxy A10 (SM-A105F, SM-A105FN, SM-A105G, SM-A105M, SM-A105N)
# Samsung Galaxy A20e (SM-A202F, SCV46)
# Samsung Galaxy A20 (SM-A205F, SM-A205FN, SM-A205G, SM-A205GN, SM-A205S, SM-A205W, SM-A205YN, SM-S205DL)
# Samsung Galaxy A30 (SM-A3050, SM-A3058, SM-A305F, SM-A305FN, SM-A305GT, SM-A305N, SM-A305YN, SCV43)
# Samsung Galaxy A30s (SM-A307FN, SM-A307G, SM-A307GN, SM-A307GT)
# Samsung Galaxy A40 (SM-A405FM SM-A405FN, SM-A405S)
# Samsung Galaxy A8 2018 (SM-A530F, SM-A530W)
# Samsung Galaxy A7 2018 (SM-A750C, SM-A750F, SM-A750FN, SM-A750N)
# Samsung Galaxy Xcover 4 (SM-G398FN)
# Samsung Galaxy J7 Duo (SM-J720F, SM-J720M)
# Samsung Galaxy M10s (SM-M107F)
# Samsung Galaxy M20 (SM-M205G, SM-M205M)
# Samsung Galaxy M30 (SM-M305F, SM-M305M)
# Samsung Galaxy Tab A 8.0 2019 (SM-P205)
# Samsung Galaxy Tab A 10.1 2019 (SM-T515, SM-T515N)
# Samsung Galaxy Tab A 10.1 2019 LTE (SM-T517, SM-T517P)
#
# Available procedures:Restore / Store Backup, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Knoxguard Remove, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset (**), Unlock / Relock Bootloader (***)
#
#
# For more detailed information, please visit our Supported models page.
#
# If you'd like to see this working check out our videos:
# Repair Serial
# ... or our two YouTube channel where you can find various educational content: ChimeraTool and ChimeraToolES.
#
#
#
# *: In most cases, it's necessary to disassemble the phone and use hardware-testpoints to put the phone into EUB mode. Visit our guides here and our Test Point Database to learn more.
# **:if Read Codes is not available on your device, please try Network Factory Reset (if the procedure button is visible) to achieve the same functionality. There are devices where none is available.
# ***: This is a beta feature, and it doesn't work on 100% of the devices, but our team is working on fully supporting the procedure.
#
#
#
#
# Software version: 39.27.1420
# Release date: 02 may 2024
#
#
#
#
# Visit our Webshop: https://chimeratool.com/shop
# Join our Telegram: https://t.me/chimeratool_offical
# Like us on Facebook: https://www.facebook.com/chimeratool
# Read our Help & Documentation: https://chimeratool.com/docs
# Get Support: https://chimeratool.com/contact
#
# GsmEasy Distributor: http://www.imei.us
# GsmServer Distributor: http://www.gsmserver.comchimera KING samsung tool
# very nicechimera is best tool in gsm markitPlease add remove mdm lock on A042F via preloader mode in next update...you are the best and yes you are the king of samsung tools go ahead.
#
# Her is the successful auto-detect and remove log of FRP S21 5G G991B U9
# Code:
#  Chimera Mobile Phone Utility version: 39.25.1235 @ 2024-05-02
# Identify
# Connecting to the phone...
# Gathering information...
# Preparing phone...
# Downloading required files...
# Processing files...
# Communicating with the phone...
# Rebooting
# This may take a while.
# Be patient! Do NOT disconnect the phone!
# Successfully finished.
# Finished at local time: [05.02.24 11:08:35]
# WorkID: 274074432
# Code:
# Chimera Mobile Phone Utility version: 39.25.1235 @ 2024-05-02
# Printing phone history
#
# Auto Detect
# 5/2/2024
# 8:13
# AM
#
# FRP Remove
# Successfully finished.
# Finished at local time: [05.02.24 11:08:50]
# WorkID: 274074529
# ======================================================================
# 8
# Title: chimera tool bug need good support s23 ultra frp fail other tool did it
# Link: https://forum.gsmhosting.com/vbb/f898/chimera-tool-bug-need-good-support-s23-ultra-frp-fail-other-tool-did-3334890/
# CreatAt:  09-09-2024
# HI team just to let you know your took have really bug almost all phone saying loader not found, its shoukd be automatic loader select we dont have do anything, and even phone connect with Qualcomm mode software still dont show it connected,
#
# s23 ultra binary 5 already support for frp, but with chimera i try giving error can not connect or loader not found, which is not right with other tool i have unlocked very easy.
# Code:
# [COLOR=#444444;][EDL] ERASE FRP[/COLOR]
#
#  Selected Model : Samsung Galaxy S23 Ultra (BIT 5)
# Code Name : SM-S918B | SM-S918B/DS (BIT5)
# Operation : Erase FRP [1]
#   Authenticating... OK
#   Retrieving data... OK [787.99 KiB]
# Initializing data... OK
# Waiting for HS-USB QDLoader 9008... COM48
# Connecting to device... OK
# Writing flash programmer... OK
# Connecting to flash programmer... OK
# Configuring device... OK
#   Firehose config : UFS [Sector:4096] [Target:0] [Host:1048576]
# Reading partition map... OK - LU Count : 6
# Reading software info... OK [super]
#    Model Name : SM-S918B_EUR_XX_QKEY1
#    Manufacturer : SAMSUNG
#    Build ID : S918BXXS5CXDE
# Erasing FRP... OK
# Rebooting... OK
#
# Elapsed time : 11 secondsDear User,
#
#
# Actually, it did not say loader not found. We have a programmer up to binary 6 for this model. Your phone was not communication with Chimera, this can be caused of a low battery or a faulty cable.
#
# Regards,
# ChimeraTeam
#
#
#
# Quote:
# Originally Posted by salim5566
# HI team just to let you know your took have really bug almost all phone saying loader not found, its shoukd be automatic loader select we dont have do anything, and even phone connect with Qualcomm mode software still dont show it connected,
#
# s23 ultra binary 5 already support for frp, but with chimera i try giving error can not connect or loader not found, which is not right with other tool i have unlocked very easy.
# Code:
# [COLOR=#444444;][EDL] ERASE FRP[/COLOR]
#
#  Selected Model : Samsung Galaxy S23 Ultra (BIT 5)
# Code Name : SM-S918B | SM-S918B/DS (BIT5)
# Operation : Erase FRP [1]
#   Authenticating... OK
#   Retrieving data... OK [787.99 KiB]
# Initializing data... OK
# Waiting for HS-USB QDLoader 9008... COM48
# Connecting to device... OK
# Writing flash programmer... OK
# Connecting to flash programmer... OK
# Configuring device... OK
#   Firehose config : UFS [Sector:4096] [Target:0] [Host:1048576]
# Reading partition map... OK - LU Count : 6
# Reading software info... OK [super]
#    Model Name : SM-S918B_EUR_XX_QKEY1
#    Manufacturer : SAMSUNG
#    Build ID : S918BXXS5CXDE
# Erasing FRP... OK
# Rebooting... OK
#
# Elapsed time : 11 secondsQuote:
# Originally Posted by Chimera Tool
# Dear User,
#
#
# Actually, it did not say loader not found. We have a programmer up to binary 6 for this model. Your phone was not communication with Chimera, this can be caused of a low battery or a faulty cable.
#
# Regards,
# ChimeraTeam
#
#
#
# hello i have use same cable so its not cable and battery was 30%
# i am just sharing you that with est point other tool can connect easily but some of the phone chimera dont connect properly.
# ======================================================================
# 9
# Title: Samsung A042F frp Help
# Link: https://forum.gsmhosting.com/vbb/f898/samsung-a042f-frp-help-3335325/
# CreatAt:  09-09-2024
# Dear supporter,Samsung A042FXXS8EXF3 FRP possible by chimera samsung tool,website shows supported,this mention binary support or not,how to find sirQuote:
# Originally Posted by salmaan64
# Dear supporter,Samsung A042FXXS8EXF3 FRP possible by chimera samsung tool,website shows supported,this mention binary support or not,how to find sir
#
# security before may patch will work in download mode.. security after may should work by tp non kg locked deviceDear friend,thanks for reply,how to find security patch,thanks.Dear User,
#
#
# You can check the fw version is recovery mode.
#
#
# Regards,
# ChimeraTeam
#
#
#
# Quote:
# Originally Posted by salmaan64
# Dear friend,thanks for reply,how to find security patch,thanks.
# ======================================================================
# 10
# Title: Samsung SM-S901B (S22 5G)(U2) IMEI REPAIR
# Link: https://forum.gsmhosting.com/vbb/f898/samsung-sm-s901b-s22-5g-u2-imei-repair-3211391/
# CreatAt:  09-09-2024
# Chimera Mobile Phone Utility version: 37.14.1001 @ 2023-10-03
# Repair started
# Gathering phone info...
# Collecting information. Be patient! Do NOT disconnect the phone!
# Model: SM-S901B
# Carrier ID: EUX
# Sales Code: BOG
# Country Code: France
# Timezone: Europe/Istanbul
# Android Version: 12 [SP1A.210812.016] [SDK 31]
# Build Date: Tue Sep 20 10:14:03 KST 2022
# PDA Version: S901BXXS2AVI7 [september 2022, rev7]
# Phone Version: S901BXXU2AVH9 [august 2022, rev9]
# CSC Version: S901BOXM2AVHB [august 2022, revB]
# Board Platform: UNIVERSAL9925
# Modem Platform: SHANNON5133AP
# Imei: XX
# Network Type: GSM
# SIM Status: ABSENT,ABSENT
# Multisim Config: DSDS
# Knox Version: v30
# Warranty Bit: 1
# Security Patch: 2022-10-01
# Em Did: 20098D8E61D00811
# Repair imei...
# Operation in progress. Be patient! Do NOT disconnect the phone!
# Servicing phone. Be patient! Do NOT disconnect the phone!
# Restarting phone
# Waiting for ADB connection. Be patient! Do NOT disconnect the phone!
# Waiting for ADB connection. Be patient! Do NOT disconnect the phone!
# Current IMEI: XX
# Repaired IMEI:XX
# Current IMEI2: XX
# Repaired IMEI2: XX
# Successfully finished.
# Finished at local time: [10.03.23 12:57:06]
# WorkID: 237451237
#
#
# ---------
#
#
# Chimera Mobile Phone Utility version: 37.14.1001 @ 2023-10-03
# Patch certificate started
# Gathering phone info...
# Collecting information. Be patient! Do NOT disconnect the phone!
# Model: SM-S901B
# Carrier ID: EUX
# Sales Code: BOG
# Country Code: France
# Timezone: Europe/Istanbul
# Android Version: 12 [SP1A.210812.016] [SDK 31]
# Build Date: Tue Sep 20 10:14:03 KST 2022
# PDA Version: S901BXXS2AVI7 [september 2022, rev7]
# Phone Version: S901BXXU2AVH9 [august 2022, rev9]
# CSC Version: S901BOXM2AVHB [august 2022, revB]
# Board Platform: UNIVERSAL9925
# Modem Platform: SHANNON5133AP
# Imei: XX
# Network Type: GSM
# SIM Status: ABSENT,ABSENT
# Multisim Config: DSDS
# Knox Version: v30
# Warranty Bit: 1
# Security Patch: 2022-10-01
# Em Did: 20098D8E61D00811
# Preparing...
# Servicing phone. Be patient! Do NOT disconnect the phone!
# Patching certificate...
# About 10-40 seconds after the phone has started, check the imei status.
# You can check the status of imei by using: *#0011#
# The patchcert can be removed by repeating the process.
# If you modify firmware, imei, csc, simlock status, or if *#0011# does not show "IMEI Status: OK", you should repeat the patchcert process.
# Successfully finished.
# Finished at local time: [10.03.23 13:00:58]
# WorkID: 237452232bro which mode to use for rebuild imei?Dear User,
#
#
# You can repair the IMEI in ADB mode.
#
#
# Regards,
# ChimeraTeam
#
#
#
# Quote:
# Originally Posted by SHIJILFONOTLY
# bro which mode to use for rebuild imei?
# ======================================================================
# 11
# Title: samsung A146vl tracephone network unlock
# Link: https://forum.gsmhosting.com/vbb/f898/samsung-a146vl-tracephone-network-unlock-3335276/
# CreatAt:  09-09-2024
# HI when i try to unlock network lock i get this message
# Code:
# Chimera Mobile Phone Utility version: 40.52.0937 @ 2024-09-09
# Network Factory Reset (Online)
# MTK bootrom mode is disabled on this device
# Finished at local time: [09.09.24 12:39:12]
# WorkID: 304954532
#
# any solution
#
#
# Code:
# Chimera Mobile Phone Utility version: 40.52.0937 @ 2024-09-09
# Printing phone history
#
# Network Factory Reset (Online)
# 9/09/2024
# 12:39
# am
#
# Get info started
# Gathering phone info...
# Collecting information. Be patient! Do NOT disconnect the phone!
# Model: SM-S146VL
# Carrier ID: TFN
# Sales Code: TFV
# Country Code: USA
# Timezone: Pacific/Auckland
# Android Version: 14 [UP1A.231005.007] [SDK 34]
# Build Date: Wed May 8 15:33:08 KST 2024
# PDA Version: S146VLUDU8CXE1 [may 2024, rev1]
# Phone Version: S146VLUDU8CXE1 [may 2024, rev1]
# CSC Version: S146VLTFN8CXE1 [may 2024, rev1]
# Board Platform: MT6833
# Modem Platform: MT6853
# Serial Number: R92X101LG0A
# Imei: 352678739643762
# Network Type: GSM
# SIM Status: NETWORK_LOCKED
# Multisim Config: SS
# Warranty Bit: 0
# Security Patch: 2024-04-01
# Em Did: C4375928574D
# Bootrom commands disabled: yes
# Successfully finished.
# Finished at local time: [09.09.24 12:39:44]
# WorkID: 304954551Dear User,
#
#
#
#
# Unfortunately, we have no solution for this problem.
#
#
# Regards,
# ChimeraTeam
#
#
#
# Quote:
# Originally Posted by salim5566
# HI when i try to unlock network lock i get this message
# Code:
# Chimera Mobile Phone Utility version: 40.52.0937 @ 2024-09-09
# Network Factory Reset (Online)
# MTK bootrom mode is disabled on this device
# Finished at local time: [09.09.24 12:39:12]
# WorkID: 304954532
# any solution
#
#
# Code:
# Chimera Mobile Phone Utility version: 40.52.0937 @ 2024-09-09
# Printing phone history
#
# Network Factory Reset (Online)
# 9/09/2024
# 12:39
# am
#
# Get info started
# Gathering phone info...
# Collecting information. Be patient! Do NOT disconnect the phone!
# Model: SM-S146VL
# Carrier ID: TFN
# Sales Code: TFV
# Country Code: USA
# Timezone: Pacific/Auckland
# Android Version: 14 [UP1A.231005.007] [SDK 34]
# Build Date: Wed May 8 15:33:08 KST 2024
# PDA Version: S146VLUDU8CXE1 [may 2024, rev1]
# Phone Version: S146VLUDU8CXE1 [may 2024, rev1]
# CSC Version: S146VLTFN8CXE1 [may 2024, rev1]
# Board Platform: MT6833
# Modem Platform: MT6853
# Serial Number: R92X101LG0A
# Imei: 352678739643762
# Network Type: GSM
# SIM Status: NETWORK_LOCKED
# Multisim Config: SS
# Warranty Bit: 0
# Security Patch: 2024-04-01
# Em Did: C4375928574D
# Bootrom commands disabled: yes
# Successfully finished.
# Finished at local time: [09.09.24 12:39:44]
# WorkID: 304954551
# ======================================================================
# 12
# Title: Successfully Flashed|Repair|Unlocked Phones With Cheetah Tool Pro
# Link: https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/
# CreatAt:  09-08-2024
# Teclast P40HD (UNISOC Tiger T606)
# FRP Done with Cheetah Tool ProA03 Core (A032F)
#
# Mdm Payjoy remved sucessfully.
#
# Waiting for device...
# Connecting port: SPRD U2S Diag (COM9)
# Soc Type : #SC9863A
# Getting identity... Okay
# Handshaking... Okay
# Sending data... Okay
#
# Verify Signature... Okay
# Sending Loaders... Okay
#
# Analysis Security... Okay
#
# Getting Device info... Okay
# ● Model Name: SM-A032F
# ● Product Name: a3corexx
# ● Manufacturer: samsung
# ● Android Version: 12
# ● Security Patch: 2023-05-01
# ● Build ID: SP1A.210812.016
# ● Display ID: SP1A.210812.016.A032FXXU3BWF2
# ● Build Date: Mon Jun 19 21:28:03 KST 2023
# ● Build: A032FXXU3BWF2
# Getting Storage info... Okay
# ● Device Internal Storage: 24.92 GB
# ● Userdata Crypto State: Encrypted?
#
#
# Remove MDM LOCK... Okay
# Wipe frp lock... Okay
#
# Reboot... Okay
#
# ● Total Time Elapsed: 26 secs, 610 msecsAlcatel 9009G Frp Sucessfully Removed
#
#
#
# Waiting for brom usb device...
# Download port: MediaTek USB Port_V1633 (COM10)
#
# Getting Device... Okay
# Handshake Device... Okay
# ● CPU Model: MT6580
# Getting Device Config... Okay
# Detect Security!
# Reading bootloader...
# Bypass SLA Protection...
# Bypass sec protection... Okay
# Dump emi config... OkayOkay
#
# Sending Loader... Okay
# Getting Chip info... Okay
# Getting device Synchronized... Okay
# Initiate RAM... Okay
# Sending DL Config... OkayOkay
#
# EMMC_INFO:
# ● EMMC_BOOT1: 4.00 MB
# ● EMMC_BOOT2: 4.00 MB
# ● EMMC_RPMB: 4.00 MB
# ● EMMC_USER: 7.28 GB
# ● EMMC_ID: 8801034E4361726420012B0F472F5567
# RAM_INFO:
# ● IN_SRAM: 128.00 KB
# ● EXT_DRAM: 1.00 GB
#
# Switch to High Speed Port... Okay
#
# Reading Partitions Table... Okay
# Getting Device info... Okay
# ● Brand Name: TCL
# ● Model Name: 9009G
# ● Product Name: 9009G
# ● Manufacturer: TCL
# ● Android Version: 8.1.0 (Oreo)
# ● Security Patch: 2019-06-05
# ● Build ID: O11019
# ● Build Date: Mon Aug 12 20:11:35 CST 2019
# ● Build: vJ65-0
# Getting Storage info... Okay
# ● Device Internal Storage: 5.22 GB
# ● Userdata Crypto State: Encrypted?
#
# Reset FRP Lock... Okay
#
# Rebooting... Okay
#
# ● Total Time Elapsed: 135 msecs
#
# WorkID: 2733990Mobicel R1 Plus 7731e FRP Remove Done
#
#
# Code:
# Waiting for device...
# Connecting port: SPRD U2S Diag (COM5)
# Soc Type :  #SC7731E
# Getting identity... Okay
# Handshaking... Okay
# Sending data... Okay
#
# Verify Signature... Okay
# Sending Loaders... Okay
#
# Analysis Security... Okay
#
# Getting Device info... Okay
#  ●  Model Name: R1PLUS_1
#  ●  Product Name: R1PLUS_1
#  ●  Manufacturer: Mobicel
#  ●  Android Version: 10 (Android 10)
#  ●  Security Patch: 2022-10-05
#  ●  Build ID: QP1A.190711.020
#  ●  Display ID: Mobicel_R1PLUS_1_DS_T_V14_20221109_MP
#  ●  Build Date: Wed Nov  9 11:22:31 CST 2022
#  ●  Build: 1667964169
# Getting Storage info... Okay
#  ● Device Internal Storage: 11.83 GB
#  ● Userdata Crypto State: Encrypted?
#
#
# Reset frp lock... Okay
#
# Reboot... Okay
#
#  ● Total Time Elapsed: 31 secs, 813 msecs
#
# WorkID: 2914083Mobicel MX2 IMEI Repair Done
#
#
# Code:
# Waiting for device...
# Connecting port: SPRD U2S Diag (COM21)
# Soc Type :  #SC7731E
# Getting identity... Okay
# Reboot to diag... Okay
# Wait for diag device...
# Getting identity... Okay
# Read device info... Okay
#  ● Platform Version: MOCORTM_17C_W21.14.6_DEBUG
#  ● Project Version: PIKE2_PUB
#  ● BASE  Version: FM_BASE_17C_W21.14.6
#  ● HW Version: SC7731E_MODEM
#  ● 04-10-2021 02: 00
# Checking new imei... Okay
#  ●  New IMEI1: 350xxxxxxxxxxxxx
#  ●  New IMEI2: 33xxxxxxxxxxxxxx
# Repairing imei... Okay
#
#  ● Total Time Elapsed: 17 secs, 950 msecs
# ======================================================================
# 13
# Title: All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro
# Link: https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/
# CreatAt:  09-07-2024
# All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro
#
#
#
# http://www.youtube.com/watch?v=_cVmDwwGf-Athank you for your shareQualcom all binaries supported brother?
# ======================================================================
# 14
# Title: Samsung A236E U6 FRP
# Link: https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/
# CreatAt:  09-07-2024
# Dear supporters,Samsung A236EXXU6EFXF3 FRP Supported this tool?
# ======================================================================
# 15
# Title: Motorola G04 read network unlock code online?
# Link: https://forum.gsmhosting.com/vbb/f1146/motorola-g04-read-network-unlock-code-online-3333554/
# CreatAt:  09-04-2024
# is Motorola G04 supported for "read network unlock code online?
# I tried but code not foundHello dear user
# which carrier?
# B.R Cheetah teamCarrier: Telstra AustraliaQuote:
# Originally Posted by mtb116
# Carrier: Telstra Australia
# Please create ticket on cheetah-tool.com
# and post your imei
# we check your problem
# B.R Cheetah teamTicket created and imei posted on your site
# ======================================================================
# 16
# Title: EFT Pro Dongle Update V4.8.1[Added Qualcomm Models for Samsung&MTK Unlock SIM Realme]
# Link: https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-8-1-added-qualcomm-models-samsung-mtk-unlock-sim-realme-3325761/
# CreatAt:  08-16-2024
# EFT Pro Dongle Update V4.8.1 Build 001 is released :
#
# What's New :
#
#
# [Qualcomm]
# - Added Qualcomm Models for Samsung
#
# ★ FRP (Factory Reset Protection)
# ★ Factory Reset
#
# Specific Models:
#
# - SM-A426U BIT6
# - SM-A526U BIT (A)
# - SM-A716U BIT9
# - SM-F711B BIT6
# - SM-F711U BIT6
# - SM-F711U BIT5
# - SM-F721B BIT4
# - SM-F721U BIT3
# - SM-F916U BIT2
# - SM-F926B BIT5
# - SM-F926B BIT4
# - SM-F926U BIT4
# - SM-F936B BIT4
# - SM-F936U BIT3
# - SM-G781U BIT6
# - SM-G781U BIT8
# - SM-G781U BIT9
# - SM-G781V BIT5
# - SM-G781W BIT (C)
# - SM-G781WV BIT (C)
#
# [MTK]
# Added Unlock SIM for Realme:
# Specific Models:
#
# - RMP2102
# - RMX3242
# - RMX3286
# - RMX3350
# - RMX3357
# - RMX3381
# - RMX3388
# - RMX3392
# - RMX3393
# - RMX3395
# - RMX3396
# - RMX3430
# - RMX3560
# - RMX3561
# - RMX3562
# - RMX3563
# - RMX3571
# - RMX3572
# - RMX3574
# - RMX3611
# - RMX3612
# - RMX3617
# - RMX3618
# - RMX3619
# - RMX3630
# - RMX3636
# - RMX3686
# - RMX3687
# - RMX3740
# - RMX3741
# - RMX3750
# - RMX3751
# - RMX3771
# - RMX3780
# - RMX3782
#
#
# More Come Soon ..........
#
#
#
#
# Previous Version EFT Pro Dongle Feature
# [MTK]
# New design and Easy menu
# Support Forced BROM (method 1)
# Support Forced BROM (method 2)
# Support Forced BROM without Test Point
# Support Samsung forced BROM (PIT Method)
# Support write Huawei (UPDATE APP) firmware
# Support write Samsung (TAR) firmware
# Support write Oppo/Realme (OFP) firmware
# Support write EMMC Dump firmware
# Support Vivo MT6765 PreLoader
# Support direct unlock network MTK (BROM)
# Support (Vivo) Disable MDM lock Supported for (2020 to Up)
# Support (Vivo) Disable MDM lock Supported for (2019)
# Support (Vivo) Disable MDM lock Supported for (Y15S PD2140EF)
# Support (Vivo) Disable demo mode
# Support (Vivo) Disable orange msg
# Support (Vivo) Restore orange msg
# Update Samsung Disable MDM Lock
# Update Samsung change KG
# Update Oppo disable MDM lock
# Support Security 2022/2023 for MTK
# Support Device for MTK devices
# Support Device (MTK) Factory Reset/FRP Reset/Write Firmware
# Update Write Samsung (TAR) Firmware
# Device (MTK) Factory Reset/FRP
# Fix Tool Dl Image Fail
# Reset Frp Lock WriteFile
# Protocol For MTK (V6)
# Protocol MTK Devices Read Info / Flash / Format / FRP
# Free Auth Tecno / Infinix / itel
# Support Models on V6 Protocol Infinix / Tecno
# Added Repair IMEI Generic (MT67XX) BROM
# Added Repair Network Security 2020/2021 BROM
# Added Repair Network Security 2022 BROM
# Added Read IMEI
# Added backup with CID number for MTK operations
# Added Forced BROM SAMSUNG Download Mode
# Added OPPO MT6771 Auth Free
# Added Samsung Auth Free
# Samsung Galaxy Wide5(SM-E426S) Auth Free
# Samsung Galaxy A13 5G(SM-A136) Auth Free
# Samsung Galaxy A22(SM-A225) Auth Free
# Samsung Galaxy F42 (SM-E426)Auth Free
# Added new DEVICE for mtk protocol (v6)
# Update GENERIC MTK V5
# Update GENERIC MTK 2023
# Added META Read Info All MTK CPU
# Added META Factory Reset All MTK CPU
# Added META Factory Reset MT62XX
# Added META Repair IMEI All MTK CPU
# Added in META Mode ( Infinix - Tecno - Itel ) All Model With Auth
# Added MTK Preloader
# Added SAMSUNG Brom Models NEW
# Added META Read Info
# Added META Factory Reset Direct (INFINIX-TECNO-ITEL)
# Added Enable/Disable Backup
# Direct Factory Reset (INFINIX-TECNO-ITEL)
#
# [SPD]
# Support models apove 200+ model
# Factory reset and FRP Reset
# Added write PAC firmware for All SPD
# Enter diag mode 2 methods
# Read info and IMEI in diag mode
# Factory reset in Diag mode ALL mode
# Added RSA AUTH Itel/Tecno/Infinix/Realme and more
# Added Spd Fix Wireless Test Assistant
# Added New Device (SPD) Factory reset/FRP Reset/Write Firmware PAC
# Read Info
# Reset FRP/Factory Reset
# Unlock Bootloader
# Relock Bootloader
# Added Info Boot Mode
# Added Read Flash /Format Disk /Write Disk
# Added Network Unlock Boot Mode
# Added Repair IMEI Boot Mode
# Added Remove MDM Boot Mode
# Added New Boot SPD V2
# Added GENERIC SPD V1
#
# [SAMSUNG]
# Fix Exynos Boot (Beta)
# Bypass Knox Samsung Adb
# Bypass Knox Samsung MTP
# Remove FRP Direct (MTP) 2023
# Enable ADB With Call Emergency #0#.
# Remove KG Lock Direct (MTP)
# Translate ADB Android 13
#
# [Qualcomm]
# Enable Diag Mode Without Root
# Added New List (Qualcomm New)
# Added list Service For (Factory Reset /FRP )
# Added list Service For (Factory Reset Oppo /FRP Oppo )
# -Qualcomm device support automatic loader
# -Support for Qualcomm devices. Select the model
# Device Support for Qualcomm devices
# Device (Qualcomm) Factory Reset/FRP
# Qualcomm Protocol Update To Support More Devices And Brands
# Fixed Read Chip Info Oppo Reno Devices
# Unlock ID (Huawei)
# Reset FRP/UserData Use Firmware (Vivo/Other)
# Device Support for Qualcomm devices
# Device (Qualcomm) Factory Reset/FRP
# Added Read flash
# Added Repair Chip damaged (Huawei)
# Update Remove ID (Huawei)
# Fix OLD loader
# Support Automatic Loader [OPPO/VIVO/HUAWEI/XIAOMI/ONEPLUS]
# Added NEW Device ALCATEL/TCL
#
# [ APPLE ]
# Added BOOT PASSCODE/HELLO IOS 16.4 IPHONE 8/8+/X
# Added BOOT PASSCODE/HELLO IOS 16.4 IPAD
# Generate Activation files ios 15.x/16.x (IPHONE/IPAD) (Without Change SN)
# FIX Boot Passcode/Hello IOS 15.x/16.x (IPAD/IPhone)
# FIX Mount Passcode/Hello IOS 11.x Up 16.x
# BOOT PASSCODE/HELLO FOR (IPAD)
# Read Account From Backup Folder
# Boot Passcode/Hello IOS 11.x Up 16.x One Click
# Change Test Signed Drivers to ON
# Read iDevice Info (Recovery Mode)
# Automatic Active Backup Restore built-in with One Click
# supported by recovery and supported by DFU
# Save info to txt file when Backup or reading from a file
# Restore Passcode with Disable Update/Reset
# Add option to format or restart if backup completes
# Ipwnder restart in case of failure
# Restore by bypass Setup and disabling Update
# Added (Jailbreak) Backup Apple with Info
# Added Disable Update/Reset/Skip Setup (One Click)
# Added Disable Update/Reset/Skip Setup Ramdisk/HELLO
#
#
# [ Rockchip ]
# Update Read/Write Flash
# Factory Reset & Frp
#
#
#
#
#
#
# More Come Soon ...
#
# Update online without replace it ...
#
#
# For New User Download File
#
# Kind Regards, Easy Firmware Team
#
#
# Get Now EFT Dongle From Nearest Distrubutor/Reseller Here
#
# EFT Tool Pro WithoutDonglewow nice update team!!!
#
# i love eft!
#
# need add a236b for frp please!
#
# Thanks for hard work!!!tool not opened now how to solveQuote:
# Originally Posted by DeVilCapo
# yes i have same error
# ======================================================================
# 17
# Title: EFT Pro Dongle Update V4.7.9[MTK Update AUTH Server - Xiaomi&Samsung New Model Added]
# Link: https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-7-9-mtk-update-auth-server-xiaomi-samsung-new-model-added-3313468/
# CreatAt:  08-04-2024
# EFT Pro Dongle Update V4.7.9 Build 001 is released :
#
# What's New :
#
#
# [MTK]
# Update AUTH Server TECNO / INFINIX
#
# ★ Read info
# ★ FRP
# ★ Factory Reset
# ★ Flash
#
#
# [Xiaomi]
# Added Models Qualcomm Xiaomi
#
# ★ Reset FRP
# ★ Factory Reset
#
# Added Models Qualcomm Samsung V3 / V4
#
# SM-S908N U4 First in the World
# SM-G970U
# SM-G970U U9
# SM-G970U1 U9
# SM-G970W U9
# SM-G970XU U9
# SM-G975U U9
# SM-G975U1 U9
# SM-G975W U9
# SM-G975XU U9
# SM-G981U U9
# SM-G981U1 U9
# SM-G981W U9
# SM-G981XU U9
# SM-G986U U8
# SM-G986U1 U8
# SM-G986W U8
# SM-G986XU U8
# Added Models Qualcomm Xiaomi
#
# Xiaomi Mi 9 Lite
# Xiaomi CC9
# Xiaomi CC9 Meitu Edition
# Xiaomi Mi 9T
# Redmi K20
# Xiaomi Mi CC9 Pro
# Xiaomi Mi Note 10
# Note 10 Lite
# Xiaomi Mi Note 10 Pro
# Xiaomi POCO X2
# Xiaomi Redmi K30
# Xiaomi Black Shark
# Xiaomi Black Shark Helo
# Xiaomi Mi 8
# Xiaomi Mi 8 Pro
# Xiaomi Mi 8 Explorer
# Xiaomi Mi Mix 2s
# Xiaomi Mi Mix 3
# Xiaomi Mi 9
# Xiaomi Mi 9T Pro
# Xiaomi Mi Mix 3 5G
# Xiaomi Black Shark 2
# Xiaomi Redmi K20 Pro
# Xiaomi Redmi 8
# Xiaomi Redmi 8A
# Xiaomi Redmi 7A
# Xiaomi Mi CC9e
# Xiaomi Redmi Note 8
# Xiaomi Redmi Note 8T
# Xiaomi Mi A3
# Xiaomi Black Shark 3
# Xiaomi Black Shark 3 Pro
# Xiaomi Black Shark 3S
# Xiaomi Mi 10 5G
# Xiaomi Mi 10 Pro 5G
# Xiaomi Mi 10 Ultra
# Xiaomi Mi 10T 5G
# Xiaomi Mi 10T Pro 5G
# Xiaomi POCO F2 Pro
# Xiaomi Redmi K30 Pro
# Xiaomi Redmi K30S
#
#
#
#
#
#
# Previous Version EFT Pro Dongle Feature
# [MTK]
# New design and Easy menu
# Support Forced BROM (method 1)
# Support Forced BROM (method 2)
# Support Forced BROM without Test Point
# Support Samsung forced BROM (PIT Method)
# Support write Huawei (UPDATE APP) firmware
# Support write Samsung (TAR) firmware
# Support write Oppo/Realme (OFP) firmware
# Support write EMMC Dump firmware
# Support Vivo MT6765 PreLoader
# Support direct unlock network MTK (BROM)
# Support (Vivo) Disable MDM lock Supported for (2020 to Up)
# Support (Vivo) Disable MDM lock Supported for (2019)
# Support (Vivo) Disable MDM lock Supported for (Y15S PD2140EF)
# Support (Vivo) Disable demo mode
# Support (Vivo) Disable orange msg
# Support (Vivo) Restore orange msg
# Update Samsung Disable MDM Lock
# Update Samsung change KG
# Update Oppo disable MDM lock
# Support Security 2022/2023 for MTK
# Support Device for MTK devices
# Support Device (MTK) Factory Reset/FRP Reset/Write Firmware
# Update Write Samsung (TAR) Firmware
# Device (MTK) Factory Reset/FRP
# Fix Tool Dl Image Fail
# Reset Frp Lock WriteFile
# Protocol For MTK (V6)
# Protocol MTK Devices Read Info / Flash / Format / FRP
# Free Auth Tecno / Infinix / itel
# Support Models on V6 Protocol Infinix / Tecno
# Added Repair IMEI Generic (MT67XX) BROM
# Added Repair Network Security 2020/2021 BROM
# Added Repair Network Security 2022 BROM
# Added Read IMEI
# Added backup with CID number for MTK operations
# Added Forced BROM SAMSUNG Download Mode
# Added OPPO MT6771 Auth Free
# Added Samsung Auth Free
# Samsung Galaxy Wide5(SM-E426S) Auth Free
# Samsung Galaxy A13 5G(SM-A136) Auth Free
# Samsung Galaxy A22(SM-A225) Auth Free
# Samsung Galaxy F42 (SM-E426)Auth Free
# Added new DEVICE for mtk protocol (v6)
# Update GENERIC MTK V5
# Update GENERIC MTK 2023
# Added META Read Info All MTK CPU
# Added META Factory Reset All MTK CPU
# Added META Factory Reset MT62XX
# Added META Repair IMEI All MTK CPU
# Added in META Mode ( Infinix - Tecno - Itel ) All Model With Auth
# Added MTK Preloader
# Added SAMSUNG Brom Models NEW
# Added META Read Info
# Added META Factory Reset Direct (INFINIX-TECNO-ITEL)
# Added Enable/Disable Backup
# Direct Factory Reset (INFINIX-TECNO-ITEL)
#
# [SPD]
# Support models apove 200+ model
# Factory reset and FRP Reset
# Added write PAC firmware for All SPD
# Enter diag mode 2 methods
# Read info and IMEI in diag mode
# Factory reset in Diag mode ALL mode
# Added RSA AUTH Itel/Tecno/Infinix/Realme and more
# Added Spd Fix Wireless Test Assistant
# Added New Device (SPD) Factory reset/FRP Reset/Write Firmware PAC
# Read Info
# Reset FRP/Factory Reset
# Unlock Bootloader
# Relock Bootloader
# Added Info Boot Mode
# Added Read Flash /Format Disk /Write Disk
# Added Network Unlock Boot Mode
# Added Repair IMEI Boot Mode
# Added Remove MDM Boot Mode
# Added New Boot SPD V2
# Added GENERIC SPD V1
#
# [SAMSUNG]
# Fix Exynos Boot (Beta)
# Bypass Knox Samsung Adb
# Bypass Knox Samsung MTP
# Remove FRP Direct (MTP) 2023
# Enable ADB With Call Emergency #0#.
# Remove KG Lock Direct (MTP)
# Translate ADB Android 13
#
# [Qualcomm]
# Enable Diag Mode Without Root
# Added New List (Qualcomm New)
# Added list Service For (Factory Reset /FRP )
# Added list Service For (Factory Reset Oppo /FRP Oppo )
# -Qualcomm device support automatic loader
# -Support for Qualcomm devices. Select the model
# Device Support for Qualcomm devices
# Device (Qualcomm) Factory Reset/FRP
# Qualcomm Protocol Update To Support More Devices And Brands
# Fixed Read Chip Info Oppo Reno Devices
# Unlock ID (Huawei)
# Reset FRP/UserData Use Firmware (Vivo/Other)
# Device Support for Qualcomm devices
# Device (Qualcomm) Factory Reset/FRP
# Added Read flash
# Added Repair Chip damaged (Huawei)
# Update Remove ID (Huawei)
# Fix OLD loader
# Support Automatic Loader [OPPO/VIVO/HUAWEI/XIAOMI/ONEPLUS]
# Added NEW Device ALCATEL/TCL
#
# [ APPLE ]
# Added BOOT PASSCODE/HELLO IOS 16.4 IPHONE 8/8+/X
# Added BOOT PASSCODE/HELLO IOS 16.4 IPAD
# Generate Activation files ios 15.x/16.x (IPHONE/IPAD) (Without Change SN)
# FIX Boot Passcode/Hello IOS 15.x/16.x (IPAD/IPhone)
# FIX Mount Passcode/Hello IOS 11.x Up 16.x
# BOOT PASSCODE/HELLO FOR (IPAD)
# Read Account From Backup Folder
# Boot Passcode/Hello IOS 11.x Up 16.x One Click
# Change Test Signed Drivers to ON
# Read iDevice Info (Recovery Mode)
# Automatic Active Backup Restore built-in with One Click
# supported by recovery and supported by DFU
# Save info to txt file when Backup or reading from a file
# Restore Passcode with Disable Update/Reset
# Add option to format or restart if backup completes
# Ipwnder restart in case of failure
# Restore by bypass Setup and disabling Update
# Added (Jailbreak) Backup Apple with Info
# Added Disable Update/Reset/Skip Setup (One Click)
# Added Disable Update/Reset/Skip Setup Ramdisk/HELLO
#
#
# [ Rockchip ]
# Update Read/Write Flash
# Factory Reset & Frp
#
#
#
#
#
#
# More Come Soon ...
#
# Update online without replace it ...
#
#
# For New User Download File
#
# Kind Regards, Easy Firmware Team
#
#
# Get Now EFT Dongle From Nearest Distrubutor/Reseller Here
#
# EFT Tool Pro WithoutDongleWait for device...
# Download port: Qualcomm HS-USB QDLoader 9008 (COM14)
# Port: Qualcomm HS-USB QDLoader 9008 (COM14)
# Manufacturer: Qualcomm Incorporated
# Waiting for server........ OK
# Connect to comport... OK
# Read chip info... OK
# OEM Private key: 0x23B7FED9A5CAF0BE38C6724E2E01CB3EAC1D30CB52213B40 71CB76B4D42EB2B7
# Vendor: GENERIC QUALCOMM
# Load loader... OK
# Send Loader... FAIL
# [PORT ERR] READ TIMED OUTQuote:
# Originally Posted by lucky999
# Wait for device...
# Download port: Qualcomm HS-USB QDLoader 9008 (COM14)
# Port: Qualcomm HS-USB QDLoader 9008 (COM14)
# Manufacturer: Qualcomm Incorporated
# Waiting for server........ OK
# Connect to comport... OK
# Read chip info... OK
# OEM Private key: 0x23B7FED9A5CAF0BE38C6724E2E01CB3EAC1D30CB52213B40 71CB76B4D42EB2B7
# Vendor: GENERIC QUALCOMM
# Load loader... OK
# Send Loader... FAIL
# [PORT ERR] READ TIMED OUT
# send me recovery phoneredmi note 10 pro mi account remove supported.?hope other Xiaomi qualcom devices add too like note 11 redmi 10c redmi note 12 note 9 pro
# ======================================================================
# 18
# Title: Nokia 2660 flip TA-1474 Factory Reset
# Link: https://forum.gsmhosting.com/vbb/f1014/nokia-2660-flip-ta-1474-factory-reset-3324963/
# CreatAt:  09-09-2024
# Error
# please check
#
#
#
#
#
#
# STOP HERE:Waiting for server.....OK
# Waiting For Device Connection.....OK
# USB PORT: SPRD U2S Diag (COM14)
# Port: SPRD U2S Diag (COM14)
# OPEN COM PORT......OK
# Handshake...OK
# Enter Diag Mode......OK
# Waiting For Device Connection......
#
#
# STOP HERE:
#
# Waiting For Device Connection......
#
# Waiting For Device Connection......Quote:
# Originally Posted by FullFlash_SL
# Error
# please check
#
#
#
#
#
#
# STOP HERE:Waiting for server.....OK
# Waiting For Device Connection.....OK
# USB PORT: SPRD U2S Diag (COM14)
# Port: SPRD U2S Diag (COM14)
# OPEN COM PORT......OK
# ...
#
#
# -: Official Telegram News Channel :-
#
#
# Telegram Channel :- https://t.me/UniAndroidTool
#
#
#
# -: Official Telegram Help & Support Group :-
#
#
# Telegram Channel :- https://t.me/Uni_Android_ToolAlways good update team...thanksCant download this. Always give error
# Incorrect format for file ./languages/sk.txt on line 1.
# Format is "variable name[tab]value"After the last update, the program opened the first time, but after closing the program it does not open again. I have tried it on 2 computers, same problem on both.
# ======================================================================
# 50
# Title: Samsung Combination flash files requests ONLY here
# Link: https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/
# CreatAt:  08-06-2024
# Please post here requests about Samsung combination flash files for all models ONLY in this THREAD!!
#
# Requests must be in format samsung standart flash file name:
# example:
#
# N950USQU4CRF3
#
# All other thread with file samsung combination file request will be deleted without warnings and explanations!!!
#
#
# ----------------------------------------
#
# Combination file details, how to check version, date, android version.
#
#
# ==============
#
# Sample: COMBINATION_OXM_FA80_G960FXXU2ARG2
#
# OXM=CSC build = [OXM]
# FA80=Android version = [Android 8]
# G960F=Phone model = [G960F]
# XXU2= Version and security BIT = [XXU,BIT2]
# ARG2= Date of release and revision = [July 2018, revision 2]
#
# ==============
#
# FA81=Android 8.1
# FA80=Android 8
# FA70=Android 7
# FA60=Android 6
# FA51=Android 5.1
# FA50=Android 5.0
# FA44=Android 4.4
# FA43=Android 4.3
# FAJP=Android JB
# FTMA=Tizen
#
# =======
#
# O=2015
# P=2016
# Q=2017
# R=2018
#
# =======
#
# A=January
# B=February
# C=March
# D=April
# E=May
# F=June
# G=July
# H=August
# I=September
# J=October
# K=November
# L=December
#
# =======
#
# 1=Revision 1
# 2=Revision 2
# 3=Revision 3
# 4=Revision 4
# 5=Revision 5
# 6=Revision 6
# 7=Revision 7
# 8=Revision 8
# 9=Revision 9
# A=Revision 10
# B=Revision 11
# C=Revision 12
# D=Revision 13
# E=Revision 14
# F=Revision 15help me a7100 Combination file neededI need SM-G6000 combination file please anyone have it please share. I wanna fix the cert of ON 7.me too
# ........................Quote:
# Originally Posted by fakeprince_
# I need SM-G6000 combination file please anyone have it please share. I wanna fix the cert of ON 7.
# check you pm to test first
#
# br
# ======================================================================
# 51
# Title: Samsung A750FN relocked again [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/samsung-a750fn-relocked-again-answered-3335412/
# CreatAt:  09-09-2024
# hi team
#
# a month ago i unlocked A750FNXXU5CTK1 using server credit , after a month later it gets relocked again , pls check it
#
#
#
# Code:
# Checking Login and Password... OK
#  Balance: 30 crd.
#  You have 30 credit(s) left. This operation takes 5 credits. Continue?  Yes
#  Waiting ADB device... OK
#  Reading phone info...
#  Model: SM-A750FN
#  Android version: 10
#  PDA version: A750FNXXU5CTK1
#  CSC version: A750FNOXM5CTK1
#  Phone version: A750FNXXU5CTK1
#  Product code: SM-A750FZKNPHE
#  CSC country code: SPAIN
#  CSC sales code: PHE
#  Carrier ID: VDI
#  Phone SN: 32009ca84b5c162b
#  IMEI: 353329103207813
#  HW version: MP0.3
#  RF cal date: 20190214
#  Chip name: EXYNOS7885
#  Modem board: SHANNON327
#  Security patch: 2020-11-01
#  Boot Warranty bit: 1
#  SIM State: ABSENT
#  Rebooting phone... OK
#  Waiting ADB device... OK
#  Waiting for device to become ready... OK
#  Checking Super user right... true
#  Root version: 23.0:MAGISKSU
#  Checking data... OK
#  Searching server... OK
#  Checking server answer... OK
#  Data preparation... OK
#  Initialization zTool... OK
#  Running zTool, please wait... OK
#  Executing 1st step... OK
#  Executing 2nd step... OK
#  Searching server... OK
#  Waiting for server answer... OK
#  Unlocking... OK
#  Rebooting phone... OKHello. Repeat operation and post result. We will refund double charged credits.its done , took again 5 crd
#
# Code:
# Checking Login and Password... OK
# Balance: 25 crd.
# You have 25 credit(s) left. This operation takes 5 credits. Continue?  Yes
# Waiting ADB device... OK
# Reading phone info...
# Model: SM-A750FN
# Android version: 10
# PDA version: A750FNXXU5CTK1
# CSC version: A750FNOXM5CTK1
# Phone version: A750FNXXU5CTK1
# Product code: SM-A750FZKNVDI
# CSC country code: SPAIN
# CSC sales code: PHE
# Carrier ID: VDI
# Phone SN: 32009ca84b5c162b
# IMEI: 353329103207813
# HW version: MP0.3
# RF cal date: 20190214
# Chip name: EXYNOS7885
# Modem board: SHANNON327
# Security patch: 2020-11-01
# Boot Warranty bit: 1
# SIM State: NETWORK_LOCKED
# Checking Super user right... true
# Root version: 23.0:MAGISKSU
# Checking data... OK
# Searching server... OK
# Checking server answer... OK
# Data preparation... OK
# Initialization zTool... OK
# Running zTool, please wait... OK
# Executing 1st step... OK
# Executing 2nd step... OK
# Searching server... OK
# Waiting for server answer... OK
# Unlocking... OK
# Rebooting phone... OK
#
# Done with Samsung Tool PRO v.45.14 [SM-A750FN,Unlock]Refunded. Check account.Quote:
# Originally Posted by Z3X
# Refunded. Check account.
# tnx for support , z3x team
# ======================================================================
# 52
# Title: sgh x510 help to unlock
# Link: https://forum.gsmhosting.com/vbb/f453/sgh-x510-help-unlock-3334782/
# CreatAt:  09-06-2024
# hi team
# any help to unlock network
# no read the phone
# Entering TestMode... Fail - Timeout
# Read info - false
# i changed the cable e700 - e850
# no any conection
#
# thanksHello. Are you using correct cable? Try plug battery during connection and hold power button.Quote:
# Originally Posted by Z3X
# Hello. Are you using correct cable? Try plug battery during connection and hold power button.
# thanks
# i do that but the same problemTry to set lower baud. If still same - check cable, check usb jack...
# ======================================================================
# 53
# Title: SAMSUNG A34 SM-A346E imei repair problem [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/samsung-a34-sm-a346e-imei-repair-problem-answered-3333452/
# CreatAt:  09-01-2024
# Hello Z3X Team a346e samsung imei repair option not support please add lastest model imei repair supporthttps://forum.gsmhosting.com/vbb/f45...hones-1642694/
# ======================================================================
# 54
# Title: A125U Unlock Error [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/a125u-unlock-error-answered-3333273/
# CreatAt:  08-31-2024
# Operation: Unlock
# Selected model: SM-A125U
# Software version: 45.14
#
# Checking Login and Password... OK
# Balance: 20 crd.
# You have 20 credit(s) left. This operation takes 5 credits. Continue? Yes
# Waiting ADB device... OK
# Reading phone info... OK
# Reading IMEI... error(0)
# Model: SM-A125U
# Android version: 12
# PDA version: A125USQU6CWG3
# CSC version: A125UOYN6CWG3
# Phone version: A125USQU6CWG3
# Product code: SM2A125UZKACHA
# CSC country code: USA
# CSC sales code: CHA
# Carrier ID: CHA
# Phone SN: R58T13CXKBM
# IMEI:
# HW version: REV1.0
# RF cal date: 20220128
# Chip name: MT6765
# Modem board: MT6765
# Security patch: 2023-06-01
# Boot Warranty bit: 0
# SIM State: ABSENT
# This phone has CSC(CHA) and CarrierId(CHA) and unlock is not supported by this method
#
# Done with Samsung Tool PRO v.45.14 [SM-A125U,Unlock]Hello. SPR only supported atm. Use chekphones: https://z3x-team.com/check-your-phone/
# ======================================================================
# 55
# Title: G991u unlock failed [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/g991u-unlock-failed-answered-3332806/
# CreatAt:  08-29-2024
# Operation: Unlock
# Selected model: SM-G991U
# Software version: 45.14
#
# Checking Login and Password... OK
# Balance: 13 crd.
# You have 13 credit(s) left. This operation takes 5 credits. Continue? Yes
# Waiting ADB device... OK
# Reading phone info... OK
# Reading IMEI... error(0)
# Model: SM-G991U
# Android version: 12
# PDA version: G991USQU5CVIF
# CSC version: G991UOYN5CVIF
# Phone version: G991USQU5CVIF
# Product code: SM-G991UZAETMB
# CSC country code: USA
# CSC sales code: TMB
# Carrier ID: TMB
# Phone SN: R5CR12736LD
# IMEI:
# HW version: REV1.0
# RF cal date: 2021.01.27
# Chip name: SM8350
# Modem board: SM8350
# Security patch: 2022-10-01
# Boot Warranty bit: 0
# SIM State: NETWORK_LOCKED,LOADED
# This phone has CSC(TMB) and CarrierId(TMB) and unlock is not supported by this method
#
# Done with Samsung Tool PRO v.45.14 [SM-G991U,Unlock]Hello.
#
# This phone has CSC(TMB) and CarrierId(TMB) and unlock is not supported by this method
#
# Use checkphones: https://z3x-team.com/check-your-phone/
# ======================================================================
# 56
# Title: S23 plus direct unlock possible? [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/s23-plus-direct-unlock-possible-answered-3332230/
# CreatAt:  08-27-2024
# Hello
# I have a s23 plus "s916" with lock attemps over (carrier lock), is possible to direct unlock or reset attemps ? tanksHello. Not possible atm. Use checkphones: https://z3x-team.com/check-your-phone/
# ======================================================================
# 57
# Title: samsung a226b u9 network lock [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/samsung-a226b-u9-network-lock-answered-3332081/
# CreatAt:  08-26-2024
# a226bxxs9dxc1 ned unlock network can i do with z3x and how many crd needHello. Currently this bit not supported. Use checkphones: https://z3x-team.com/check-your-phone/
# ======================================================================
# 58
# Title: Please Update samsungtool with New desing [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/please-update-samsungtool-new-desing-answered-3331723/
# CreatAt:  08-25-2024
# Hello, please Update z3x Samsung tool pro with New desing theme, please add New featuresHello. We working on update.
# ======================================================================
# 59
# Title: samsung a705FN cert patch? [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/samsung-a705fn-cert-patch-answered-3331219/
# CreatAt:  08-25-2024
# good evening. the phone is SM-A705FN, the imei in my phone is in place, but there is no network, a certificate patch is required. how to restore the network?Hello. Its qualcomm phone. Qualcomm not supported at all for patch.[ЦИТАТА=Z3X;15035010]Привет. Его телефон qualcomm. Qualcomm вообще не поддерживается для патча.[/ЦИТАТА]
#
# Then how do I restore the network on this phone?Quote:
# Originally Posted by kastens
# [ЦИТАТА=Z3X;15035010]Привет. Его телефон qualcomm. Qualcomm вообще не поддерживается для патча.[/ЦИТАТА]
#
# Then how do I restore the network on this phone?
# Currently there is no repair/patch option for qualcomm phones.
# ======================================================================
# 60
# Title: An important question about Z3X Samsung update and support
# Link: https://forum.gsmhosting.com/vbb/f453/important-question-about-z3x-samsung-update-support-3330256/
# CreatAt:  08-23-2024
# Hello to the Z3X team
#
# Considering that it's been almost a year since there has been any update for the Samsung section, and most of the new models and security patches are not supported by this tool, and given that many users in this forum have been asking whether the Samsung section will receive an update or if the Z3X team intends to focus solely on the Pandora box, could you please provide a response so that the users are informed? It's been a long time since the last update, and there has been no notification regarding this matter. Thank youHello. No, we preparing some big update. Wait please.How long will it take, days, weeks or months?
#
# Please tell me somethingQuote:
# Originally Posted by Malik Shani G
# How long will it take, days, weeks or months?
#
# Please tell me something
# As soon as it will be ready for release.Quote:
# Originally Posted by Z3X
# Hello. No, we preparing some big update. Wait please.
# But we saw new directory for exynos created to pandora. Is it that Samsung tool pro was a waste project,We bought activation plus credits, we even bought special hardware pandora only to get online. is it going to be dead box(samsung tool pro?)Thats the main concern for all Samsung tool pro users
# ======================================================================
# 61
# Title: Samsng n975u unlock error [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/samsng-n975u-unlock-error-answered-3329583/
# CreatAt:  08-19-2024
# Operation: Read Codes via Server
# Selected model: SM-N975U
# Software version: 45.14
# Checking Login and Password... OK
# Balance: 5 crd.
# You have 5 credit(s) left. This operation takes 5 credits. Continue? Yes
# Waiting for device to become ready... OK
# Reading phone info...
# Model: SM-N975U
# Android version: 11
# PDA version: N975USQS6FUF2
# CSC version: N975UOYN6FUF2
# Phone version: N975USQS6FUF2
# Product code: SM-N975UZKEATT
# CSC country code: USA
# CSC sales code: ATT
# Carrier ID: ATT
# Phone SN: RF8M804P7PM
# IMEI: 359188100372143
# HW version: REV1.0
# RF cal date: 2019.08.01
# Chip name: SM8150
# Modem board: SM8150
# Security patch: 2021-07-01
# Boot Warranty bit: 0
# SIM State: ABSENT
# Initialization zTool... error (1)
#
# Done with Samsung Tool PRO v.45.14 [SM-N975U,Read Codes via Server]Hello. This bit not supported. Use checkphones: https://z3x-team.com/check-your-phone/
# ======================================================================
# 62
# Title: J330 unlock not done [Answered]
# Link: https://forum.gsmhosting.com/vbb/f453/j330-unlock-not-done-answered-2938791/
# CreatAt:  08-18-2024
# please help regarding this unlock.
#
# Here is the log:
#
# Operation: Read Codes via Server
# Selected model: SM-J330FN
# Software version: 41.11
#
# Checking Login and Password... OK
# Ballance: 30 crd.
# You have 30 credit(s) left. This operation takes 5 credits.Continue? Yes
# Waiting ADB device... OK
# Reading phone info...
# Model: SM-J330FN
# Android version: 9
# PDA version: J330FNXXU4CTH2
# CSC version: J330FNVFG4CTH2
# Phone version: J330FNXXU4CTH2
# Product code: SM2J330FZKNCNX
# CSC country code: Romania
# CSC sales code: CNX
# Phone SN: R58K54LWSKM
# IMEI: 358952082260860
# HW version: MP 0.500
# RF cal date: 20180525
# Chip name: EXYNOS7570
# Modem board: SHANNON305
# Security patch: 2020-09-01
# Boot Warranty bit: 0
# SIM State: ABSENT
# Rebooting phone... OK
# Waiting ADB device... OK
# Initialization zTool... OK
# Running zTool, please wait... OK
# Reading data from phone... OK
# Searching Ramdump interface... COM50 detected
# Reading data from phone... error (1)
# Done with Samsung Tool PRO v.41.11Hello. Just reset phone settings and repeat once again. Post result here.Waiting ADB device... OK
# Reading phone info...
# Model: SM-J330FN
# Android version: 9
# PDA version: J330FNXXS4CUD3
# CSC version: J330FNVFG4CTH2
# Phone version: J330FNXXS4CUD3
# Product code: SM2J330FZKNCNX
# CSC country code: Romania
# CSC sales code: CNX
# Phone SN: R58K71A9V5T
# IMEI: 358952086301876
# HW version: MP 0.500
# RF cal date: 20180709
# Chip name: EXYNOS7570
# Modem board: SHANNON305
# Security patch: 2021-04-01
# Boot Warranty bit: 1
# SIM State: ABSENT
# Initialization zTool Loader... OK
# Running zTool, please wait... OK
# Loading... OK
# Initialization zTool... OK
# Running zTool, please wait... OK
# Executing... OK
# Searching Ramdump interface... COM18 detected
# Reading data from phone...error (1)
#
# Same error, same problem, same network
#
# Have you solve it?Quote:
# Originally Posted by zmeutz
# Waiting ADB device... OK
# Reading phone info...
# Model: SM-J330FN
# Android version: 9
# PDA version: J330FNXXS4CUD3
# CSC version: J330FNVFG4CTH2
# Phone version: J330FNXXS4CUD3
# Product code: SM2J330FZKNCNX
# CSC country code: Romania
# CSC sales code: CNX
# Phone SN: R58K71A9V5T
# IMEI: 358952086301876
# HW version: MP 0.500
# RF cal date: 20180709
# Chip name: EXYNOS7570
# Modem board: SHANNON305
# Security patch: 2021-04-01
# Boot Warranty bit: 1
# SIM State: ABSENT
# Initialization zTool Loader... OK
# Running zTool, please wait... OK
# Loading... OK
# Initialization zTool... OK
# Running zTool, please wait... OK
# Executing... OK
# Searching Ramdump interface... COM18 detected
# Reading data from phone...error (1)
#
# Same error, same problem, same network
#
# Have you solve it?
# Hello. This bit supported via upload algo only, this algo not works with knox 1.Ok, thanks....
# I will try online unlock, do you have service?
# ======================================================================

# %%
from transformers import pipeline

# gen model
summarizer = pipeline("summarization")

# sumary text
text = """
Your max_length is set to 50, but your input_length is only 11. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
your long text or conversation goes here . if you have a long text, send a text or a conversation .
"""
summary = summarizer(text, min_length=0, do_sample=False)
print(summary[0]['summary_text'])
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From c:\Users\SyLV\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\SyLV\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Your max_length is set to 142, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
#  Your max_length is set to 50, but your input is only 11 . If you have a long text, send a text or a conversation to summarizer .

# %%
# sumary
# stt = 0
# for ans in list_answers:
#     long_text = "".join(ans[0:5])
#     length = len(long_text)
#     res = []
#     stt += 1
#     print (f'Sumary {stt}: {length} {length//2}')
#     if (length > 10):
#         res = summarizer(long_text, min_length=0, do_sample=False)
#         print(res[0]['summary_text'])
#     else :
#         print (long_text)
print('Success')
# Out:
# Success
